# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# tidore id
# hermanus za
# carnarvon au
# inta ru
# polonnaruwa lk
# aksarka ru
# vostok ru
# nanticoke ca
# cape town za
# taolanaro mg
# bethel us
# liverpool ca
# makakilo city us
# cherskiy ru
# belmonte br
# arona es
# new norfolk au
# korla cn
# alice springs au
# taolanaro mg
# tuatapere nz
# illoqqortoormiut gl
# punta arenas cl
# butaritari ki
# puerto ayora ec
# opuwo na
# kodiak us
# albany au
# wajir ke
# walvis bay na
# mukhen ru
# razole in
# tiksi ru
# lavrentiya ru
# jamestown sh
# sicamous ca
# mataura pf
# dikson ru
# lazarev ru
# snasa no
# grand river south east mu
# olafsvik is
# clyde river ca
# barrow us
# santana br
# axim gh
# saskylakh ru
# new norfolk au
# presidencia roque saenz pena ar
# mwense zm
# torbay ca
# iqaluit ca
# kapaa us
# caravelas br
# charters towers au
# lavrentiya ru
# ushuaia ar
# walvis bay na
# grand river south east mu
# rikitea pf
# chuy uy
# hermanus za
# saint-pierre pm
# mataura pf
# hermanus za
# lata sb
# coro ve
# cherskiy ru
# albany au
# lompoc us
# clyde river ca
# hermanus za
# qaanaaq gl
# provideniya ru
# portoferraio it
# ushuaia ar
# ruatoria nz
# sorvag fo
# basco ph
# tasiilaq gl
# taksimo ru
# georgetown sh
# rikitea pf
# quarai br
# punta arenas cl
# yangambi cd
# owando cg
# hasaki jp
# torbay ca
# puerto ayora ec
# paamiut gl
# banda aceh id
# nizhneyansk ru
# castro cl
# tasiilaq gl
# broome au
# albany au
# el alto pe
# atuona pf
# lompoc us
# hualmay pe
# barentsburg sj
# tiksi ru
# butaritari ki
# carnarvon au
# jamestown sh
# bluff nz
# jamestown sh
# siniscola it
# sitka us
# mar del plata ar
# qaanaaq gl
# nanortalik gl
# sitka us
# luderitz na
# vaini to
# andenes no
# hithadhoo mv
# tiruvannamalai in
# reefton nz
# nioki cd
# pattaya th
# emba kz
# albany au
# constitucion mx
# goderich sl
# clyde river ca
# vila velha br
# nanortalik gl
# bluff nz
# mataura pf
# vanavara ru
# blyznyuky ua
# deniliquin au
# punta arenas cl
# canitas mx
# sao felix do xingu br
# hovd mn
# temaraia ki
# wuwei cn
# mayumba ga
# belushya guba ru
# saskylakh ru
# sentyabrskiy ru
# chapais ca
# punta arenas cl
# bambous virieux mu
# yellowknife ca
# jamestown sh
# rikitea pf
# vila franca do campo pt
# chuy uy
# grand river south east mu
# nikolskoye ru
# brighton ca
# amderma ru
# varhaug no
# atuona pf
# cherskiy ru
# grand river south east mu
# tsiroanomandidy mg
# ulaanbaatar mn
# thompson ca
# hilo us
# tarauaca br
# port alfred za
# nikolskoye ru
# mataura pf
# quang ngai vn
# taolanaro mg
# georgetown sh
# nelson bay au
# svetlogorsk ru
# khatanga ru
# belushya guba ru
# lebu cl
# baiquan cn
# nikolskoye ru
# mataura pf
# kruisfontein za
# caravelas br
# rikitea pf
# lompoc us
# poronaysk ru
# cape town za
# tiksi ru
# mataura pf
# qandahar af
# bluff nz
# ushuaia ar
# rikitea pf
# mnogovershinnyy ru
# safwah sa
# ribeira grande pt
# meadow lake ca
# roma au
# hilo us
# airai pw
# shihezi cn
# provideniya ru
# athabasca ca
# nkhotakota mw
# lavrentiya ru
# yakeshi cn
# port alfred za
# bluff nz
# hobart au
# cabo san lucas mx
# voi ke
# flin flon ca
# belushya guba ru
# albany au
# atuona pf
# albany au
# taolanaro mg
# tommot ru
# vaini to
# lorengau pg
# moerai pf
# bakloh in
# port alfred za
# norman wells ca
# hobart au
# kalinovskaya ru
# bluff nz
# tual id
# barrow us
# mataura pf
# kangaatsiaq gl
# adrar dz
# grindavik is
# lipari it
# castro cl
# sataua ws
# punta arenas cl
# cabo san lucas mx
# qaanaaq gl
# yining cn
# pasaje ec
# nanortalik gl
# ushuaia ar
# santa isabel mx
# cape town za
# provideniya ru
# ushuaia ar
# ancud cl
# mar del plata ar
# dikson ru
# rikitea pf
# jamestown sh
# sambava mg
# kamaishi jp
# shalya ru
# puerto ayora ec
# stepnyak kz
# qaanaaq gl
# punta arenas cl
# inhambane mz
# attawapiskat ca
# novikovo ru
# yar-sale ru
# rikitea pf
# belaya gora ru
# northam au
# provideniya ru
# east london za
# punta arenas cl
# alto araguaia br
# upata ve
# biak id
# saskylakh ru
# mataura pf
# college us
# praia cv
# bredasdorp za
# dikson ru
# roald no
# mitu co
# gornozavodsk ru
# maniitsoq gl
# naze jp
# el tigre ve
# puerto ayora ec
# leningradskiy ru
# guerrero negro mx
# shimoda jp
# butaritari ki
# bluff nz
# illoqqortoormiut gl
# alihe cn
# rikitea pf
# santo tomas pe
# nikolskoye ru
# rikitea pf
# saint anthony ca
# kaitangata nz
# nizhneyansk ru
# belushya guba ru
# esperance au
# hermanus za
# port-gentil ga
# bay roberts ca
# fairlie nz
# katsuura jp
# cayenne gf
# georgetown sh
# butaritari ki
# monrovia lr
# hermanus za
# richards bay za
# kirakira sb
# bluff nz
# chokurdakh ru
# srednekolymsk ru
# clyde river ca
# pisco pe
# marzuq ly
# saskylakh ru
# new norfolk au
# yerofey pavlovich ru
# kodiak us
# georgetown sh
# butaritari ki
# punta arenas cl
# albertville us
# avarua ck
# codrington ag
# kindu cd
# poum nc
# januaria br
# vila franca do campo pt
# rikitea pf
# bluff nz
# fortuna us
# punta arenas cl
# nuuk gl
# ushuaia ar
# attawapiskat ca
# saint-joseph re
# mataura pf
# cape town za
# rikitea pf
# hilo us
# ushuaia ar
# bluff nz
# elko us
# rio grande br
# vaitupu wf
# bilibino ru
# tiksi ru
# srednekolymsk ru
# albany au
# raboso mx
# coihaique cl
# ushuaia ar
# taolanaro mg
# kavieng pg
# arraial do cabo br
# san cristobal ec
# rikitea pf
# vestmanna fo
# urubicha bo
# tuktoyaktuk ca
# sentyabrskiy ru
# tuktoyaktuk ca
# hermanus za
# olga ru
# kupang id
# itoman jp
# kidal ml
# ushuaia ar
# vila franca do campo pt
# kapaa us
# montepuez mz
# saurimo ao
# vestmannaeyjar is
# taolanaro mg
# kapaa us
# gobabis na
# tura ru
# kapaa us
# talnakh ru
# marrakesh ma
# provideniya ru
# vaitupu wf
# topolobampo mx
# saint-philippe re
# ulaangom mn
# taltal cl
# tuktoyaktuk ca
# hobart au
# sibolga id
# ushuaia ar
# devyatka ru
# soyo ao
# bozoum cf
# bluff nz
# georgetown sh
# jumla np
# hobart au
# upernavik gl
# new waterford ca
# lebu cl
# butaritari ki
# faanui pf
# avarua ck
# hobart au
# sao filipe cv
# taolanaro mg
# busselton au
# srednekolymsk ru
# bakchar ru
# kapaa us
# arraial do cabo br
# albany au
# tsihombe mg
# busselton au
# punta arenas cl
# mataura pf
# bowen au
# rikitea pf
# bluff nz
# wahran dz
# aswan eg
# komsomolskiy ru
# juifang tw
# mukhen ru
# taltal cl
# hithadhoo mv
# neryungri ru
# mataura pf
# east london za
# hobart au
# jamestown sh
# pevek ru
# grindavik is
# puerto ayora ec
# bayburt tr
# kruisfontein za
# mataura pf
# rikitea pf
# mattoon us
# taolanaro mg
# hamilton bm
# jamestown sh
# hilo us
# pampierstad za
# arlit ne
# mogadishu so
# roxana cr
# mataura pf
# mataura pf
# kruisfontein za
# belyy yar ru
# ushuaia ar
# singarayakonda in
# arraial do cabo br
# punta arenas cl
# abu samrah qa
# albany au
# atuona pf
# neiafu to
# rikitea pf
# jamestown sh
# vinga ro
# maun bw
# kavieng pg
# rikitea pf
# taolanaro mg
# raudeberg no
# avarua ck
# saldanha za
# tura ru
# rikitea pf
# mehamn no
# oranjemund na
# ekhabi ru
# atar mr
# butaritari ki
# bluff nz
# chalon-sur-saone fr
# busselton au
# chapais ca
# kulhudhuffushi mv
# chokurdakh ru
# verkhnevilyuysk ru
# nemuro jp
# egvekinot ru
# usinsk ru
# ushuaia ar
# olinda br
# busselton au
# avarua ck
# upernavik gl
# cumaribo co
# hermanus za
# zhangjiakou cn
# hobart au
# attawapiskat ca
# saint anthony ca
# baykit ru
# busselton au
# hovd mn
# punta arenas cl
# mataura pf
# hofn is
# ipora br
# kaitangata nz
# upernavik gl
# hobart au
# rikitea pf
# tuatapere nz
# ushuaia ar
# puerto ayora ec
# hasaki jp
# ushuaia ar
# khatanga ru
# arraial do cabo br
# port elizabeth za
# hermanus za
# barrow us
# busselton au
# murgab tm
# belyy yar ru
# mys shmidta ru
# leh in
# ilulissat gl
# upernavik gl
# maniitsoq gl
# belushya guba ru
# bachaquero ve
# rikitea pf
# yellowknife ca
# bredasdorp za
# mizpe ramon il
# kaitangata nz
# hilo us
# formosa ar
# wharton us
# ushuaia ar
# carutapera br
# vaini to
# rikitea pf
# hermanus za
# senneterre ca
# saskylakh ru
# kununurra au
# sucre bo
# arraial do cabo br
# kavieng pg
# blagoyevo ru
# albany au
# toora-khem ru
# hithadhoo mv
# atuona pf
# mizdah ly
# konotop ua
# clyde river ca
# atuona pf
# castro cl
# bereznehuvate ua
# saskylakh ru
# bijawar in
# mar del plata ar
# iqaluit ca
# santos reyes nopala mx
# punta arenas cl
# talawdi sd
# hermanus za
# ushuaia ar
# biak id
# cockburn town tc
# port hardy ca
# sentyabrskiy ru
# padang id
# amderma ru
# punta arenas cl
# barrow us
# albany au
# severo-kurilsk ru
# chokurdakh ru
# port alfred za
# geri cy
# yithion gr
# ordynskoye ru
# atar mr
# saskylakh ru
# grand river south east mu
# namibe ao
# manzhouli cn
# arraial do cabo br
# sao filipe cv
# cape town za
# los llanos de aridane es
# mataura pf
# fuyang cn
# jamestown sh
# bredasdorp za
# tyup kg
# coquimbo cl
# balagansk ru
# broken hill au
# ballina ie
# ostrovnoy ru
# kahului us
# rikitea pf
# san patricio mx
# hilo us
# maragogi br
# verkh-usugli ru
# mataura pf
# busselton au
# hermanus za
# nirmal in
# cherskiy ru
# busselton au
# mahajanga mg
# busselton au
# hofn is
# kavaratti in
# butaritari ki
# busselton au
# ushuaia ar
# ushuaia ar
# new norfolk au
# new norfolk au
# savannah bight hn
# cape town za
# punta arenas cl
# vaini to
# busselton au
# tuktoyaktuk ca
# hasaki jp
# atuona pf
# nome us
# sayalgudi in
# atuona pf
# port alfred za
# rikitea pf
# havre-saint-pierre ca
# touba ci
# mayor pablo lagerenza py
# saint-georges gf
# vaitupu wf
# hermanus za
# alikalia sl
# nizhneyansk ru
# albany au
# port hedland au
# shuangyang cn
# upernavik gl
# severnoye ru
# vardo no
# new norfolk au
# dahegam in
# vaini to
# mataura pf
# mehamn no
# mataura pf
# kutum sd
# kruisfontein za
# barrow us
# hobart au
# ushuaia ar
# vaitupu wf
# richards bay za
# juneau us
# luderitz na
# new norfolk au
# busselton au
# palabuhanratu id
# hithadhoo mv
# luderitz na
# eureka us
# longyearbyen sj
# apache junction us
# busselton au
# skelleftea se
# coroico bo
# hualmay pe
# amderma ru
# te anau nz
# livingston us
# nguiu au
# lima pe
# umm kaddadah sd
# majene id
# hailar cn
# albany au
# grindsted dk
# yar-sale ru
# klaksvik fo
# lakselv no
# rikitea pf
# richards bay za
# taolanaro mg
# iqaluit ca
# san patricio mx
# rio grande br
# antalaha mg
# rikitea pf
# atuona pf
# saint-philippe re
# belushya guba ru
# casma pe
# mount isa au
# cape town za
# cape town za
# ushuaia ar
# rikitea pf
# alice springs au
# atherton au
# dunedin nz
# belmonte br
# thompson ca
# yellowknife ca
# hermanus za
# kapaa us
# hobart au
# aklavik ca
# saleaula ws
# chuy uy
# nikolskoye ru
# albany au
# salinas ec
# kieta pg
# pevek ru
# ponta do sol cv
# kabalo cd
# busselton au
# barrow us
# albany au
# mar del plata ar
# bayburt tr
# saskylakh ru
# atuona pf
# stornoway gb
# flinders au
# cape town za
# sharjah ae
# qaanaaq gl
# asau tv
# leningradskiy ru
# alpena us
# mvuma zw
# barrow us
# waremme be
# annau tm
# voka ee
# puerto ayora ec
# chuy uy
# snezhnogorsk ru
# yellowknife ca
# fortuna us
# ilulissat gl
# atuona pf
# port alfred za
# avarua ck
# punta arenas cl
# rikitea pf
# castro cl
# severo-kurilsk ru
# tazovskiy ru
# kununurra au
# albany au
# hobart au
# garm tj
# ostrovnoy ru
# illoqqortoormiut gl
# iqaluit ca
# kikwit cd
# buariki ki
# new norfolk au
# cape town za
# hai duong vn
# koshurnikovo ru
# sao miguel do araguaia br
# punta arenas cl
# kijabe ke
# vitim ru
# cape town za
# bredasdorp za
# arraial do cabo br
# avarua ck
# kapaa us
# kitimat ca
# jhinjhak in
# tuktoyaktuk ca
# busselton au
# coihaique cl
# jamestown sh
# new norfolk au
# punta arenas cl
# nanortalik gl
# inirida co
# qaanaaq gl
# punta arenas cl
# san patricio mx
# tahta eg
# ushuaia ar
# avarua ck
# la ronge ca
# puerto ayora ec
# homer us
# saskylakh ru
# hithadhoo mv
# georgetown sh
# port alfred za
# mataura pf
# ribeira grande pt
# arraial do cabo br
# clyde river ca
# busselton au
# port elizabeth za
# lebu cl
# bargal so
# dimapur in
# berlevag no
# port augusta au
# vaini to
# rikitea pf
# vila velha br
# moranbah au
# saldanha za
# grindavik is
# puerto ayora ec
# takoradi gh
# busselton au
# marsh harbour bs
# kieta pg
# senneterre ca
# erzin ru
# hermanus za
# waipawa nz
# bardiyah ly
# qasigiannguit gl
# taolanaro mg
# taolanaro mg
# new norfolk au
# ushuaia ar
# vilhena br
# brejinho br
# ushuaia ar
# hasaki jp
# rikitea pf
# iqaluit ca
# manaure co
# nova olinda do norte br
# lagoa pt
# ushuaia ar
# cidreira br
# kaga jp
# taolanaro mg
# cape town za
# cape town za
# sokoni tz
# cape town za
# punta arenas cl
# taolanaro mg
# lithakia gr
# richards bay za
# samusu ws
# atuona pf
# galveston us
# spassk ru
# hermanus za
# mar del plata ar
# rikitea pf
# mar del plata ar
# sitka us
# challapata bo
# saskylakh ru
# qaanaaq gl
# barentsburg sj
# voyinka ua
# branistea ro
# paamiut gl
# zhiryatino ru
# busselton au
# lima pe
# kijang id
# saryg-sep ru
# punta arenas cl
# jamestown sh
# mataura pf
# plettenberg bay za
# cambridge gb
# arica cl
# ushuaia ar
# vaini to
# vaini to
# bambous virieux mu
# samarai pg
# saint-philippe re
# nyurba ru
# vaini to
# chokurdakh ru
# hithadhoo mv
# malindi ke
# leningradskiy ru
# hermanus za
# geraldton ca
# new norfolk au
# rikitea pf
# punta arenas cl
# puerto ayora ec
# bethel us
# vaini to
# gamba ga
# tandalti sd
# victoria sc
# kuala terengganu my
# verkhnyaya salda ru
# taolanaro mg
# rikitea pf
# ushuaia ar
# srednekolymsk ru
# tabarqah tn
# izvestkovyy ru
# barra da estiva br
# port hedland au
# taolanaro mg
# hobart au
# jamestown sh
# cape town za
# morondava mg
# neutraubling de
# sukkur pk
# sokoni tz
# hermanus za
# teya ru
# albany au
# albany au
# samalaeulu ws
# mys shmidta ru
# kapaa us
# rikitea pf
# valera ve
# devonport au
# punta arenas cl
# vysokogornyy ru
# youghal ie
# san cristobal ec
# forssa fi
# olot uz
# vila velha br
# blenheim ca
# alice springs au
# mehamn no
# chunskiy ru
# batie bf
# meulaboh id
# amderma ru
# los llanos de aridane es
# butaritari ki
# jamestown sh
# kilindoni tz
# kijang id
# palabuhanratu id
# mount isa au
# chuy uy
# payakumbuh id
# puerto del rosario es
# nouadhibou mr
# saint-philippe re
# attawapiskat ca
# arraial do cabo br
# vaini to
# tsuruga jp
# belushya guba ru
# cape town za
# busselton au
# rodrigues alves br
# taolanaro mg
# los llanos de aridane es
# port-cartier ca
# atuona pf
# atuona pf
# klaksvik fo
# saint-philippe re
# shibarghan af
# laguna br
# jamestown sh
# alpena us
# arlit ne
# villa oliva py
# leningradskiy ru
# isla mujeres mx
# north myrtle beach us
# albany au
# veraval in
# avarua ck
# rikitea pf
# kholodnyy ru
# busselton au
# barrow us
# lima pe
# nome us
# hobart au
# mataura pf
# yellowknife ca
# mataura pf
# san cristobal ec
# albany au
# zakamensk ru
# becerril co
# new norfolk au
# jamestown sh
# geraldton au
# ayagoz kz
# dingle ie
# mar del plata ar
# punta arenas cl
# talakan ru
# shelby us
# thompson ca
# jamestown sh
# puerto ayora ec
# port elizabeth za
# ancud cl
# georgetown sh
# hobart au
# port alfred za
# albany au
# ulaangom mn
# atuona pf
# la ronge ca
# yellowknife ca
# bathsheba bb
# rikitea pf
# paamiut gl
# san agustin acasaguastlan gt
# sentyabrskiy ru
# celestun mx
# ulcinj me
# borgo san lorenzo it
# vaini to
# hilo us
# taolanaro mg
# ushuaia ar
# marsa matruh eg
# ponta delgada pt
# hofn is
# punta arenas cl
# san antonio hn
# ushuaia ar
# kapaa us
# duobao cn
# taolanaro mg
# cabinda ao
# paamiut gl
# severo-kurilsk ru
# ternate id
# upernavik gl
# busselton au
# padang id
# kapaa us
# polovinnoye ru
# oktyabrskoye ru
# mount isa au
# kapaa us
# tomatlan mx
# albany au
# umm kaddadah sd
# athabasca ca
# hilo us
# puerto ayora ec
# alofi nu
# montelibano co
# yellowknife ca
# puerto ayora ec
# albany au
# avarua ck
# port elizabeth za
# neka ir
# sao joao da barra br
# ushuaia ar
# caravelas br
# touros br
# jamestown sh
# carutapera br
# general roca ar
# bestobe kz
# avarua ck
# padang id
# karratha au
# jamestown sh
# bahia honda cu
# puerto ayora ec
# susehri tr
# tsihombe mg
# christchurch nz
# husavik is
# illoqqortoormiut gl
# toliary mg
# necochea ar
# jabinyanah tn
# vaini to
# faya td
# den helder nl
# arraial do cabo br
# rikitea pf
# la palma pa
# albany au
# provideniya ru
# esperance au
# nizhneyansk ru
# praia da vitoria pt
# itupiranga br
# ostrovnoy ru
# carnarvon au
# khatanga ru
# barentsburg sj
# te anau nz
# mananjary mg
# upernavik gl
# geraldton au
# san patricio mx
# luganville vu
# rikitea pf
# comodoro rivadavia ar
# westport ie
# bluff nz
# rikitea pf
# bredasdorp za
# hithadhoo mv
# bluff nz
# atuona pf
# attawapiskat ca
# rikitea pf
# sitka us
# cherskiy ru
# jamestown sh
# codrington ag
# kodiak us
# punta arenas cl
# hithadhoo mv
# new norfolk au
# vaini to
# kuytun cn
# isla vista us
# calabozo ve
# portland au
# muravlenko ru
# butaritari ki
# atuona pf
# kodiak us
# albany au
# rio grande br
# mys shmidta ru
# kahului us
# rikitea pf
# rikitea pf
# ramsgate gb
# jamestown sh
# santa vitoria do palmar br
# winneba gh
# impfondo cg
# port elizabeth za
# lompoc us
# ugoofaaru mv
# victoria sc
# ushuaia ar
# puerto gaitan co
# punta arenas cl
# safaga eg
# carnarvon au
# busselton au
# salalah om
# rikitea pf
# scarborough gb
# chuy uy
# taolanaro mg
# jamestown sh
# zhigansk ru
# marabba sd
# nizhneyansk ru
# amderma ru
# clyde river ca
# pisco pe
# illoqqortoormiut gl
# lompoc us
# kamenskoye ru
# mar del plata ar
# ugoofaaru mv
# tripoli ly
# vestmannaeyjar is
# upata ve
# bandarbeyla so
# baykit ru
# lima pe
# port alfred za
# ostrovnoy ru
# jamestown sh
# yellowknife ca
# pangai to
# vaini to
# rikitea pf
# chokurdakh ru
# bartica gy
# bandarbeyla so
# naugarzan tj
# marienburg sr
# hilo us
# praia da vitoria pt
# galveston us
# cidreira br
# souillac mu
# ushuaia ar
# hermanus za
# atuona pf
# klaksvik fo
# jasper ca
# airai pw
# yar-sale ru
# mahebourg mu
# nikolskoye ru
# saint-philippe re
# tiksi ru
# codrington ag
# santa rosa del sur co
# hasaki jp
# naze jp
# atuona pf
# atuona pf
# ushuaia ar
# clyde river ca
# hvide sande dk
# lienz at
# temaraia ki
# busselton au
# hobyo so
# vila velha br
# hilo us
# albany au
# butaritari ki
# poum nc
# ilulissat gl
# broome au
# fairbanks us
# jamestown sh
# kapaa us
# new norfolk au
# lagoa pt
# horana lk
# bambous virieux mu
# busselton au
# kollegal in
# salinopolis br
# methoni gr
# mar del plata ar
# vaitupu wf
# carnarvon au
# northam au
# illoqqortoormiut gl
# bar-le-duc fr
# saint-philippe re
# carauari br
# dunedin nz
# saint-philippe re
# qiongshan cn
# porto novo cv
# north bend us
# mount gambier au
# punta arenas cl
# sayat tm
# mitsamiouli km
# trapani it
# barrow us
# bredasdorp za
# tsihombe mg
# mataura pf
# mae sai th
# ushuaia ar
# cape town za
# cape town za
# punta arenas cl
# mataura pf
# narsaq gl
# lagoa pt
# rikitea pf
# arraial do cabo br
# mataura pf
# dikson ru
# beloha mg
# halifax ca
# qaanaaq gl
# ushuaia ar
# faanui pf
# airai pw
# athabasca ca
# bluff nz
# saleaula ws
# hermanus za
# petropavlovsk-kamchatskiy ru
# souillac mu
# ushuaia ar
# punta arenas cl
# lata sb
# bredasdorp za
# khatanga ru
# lao cai vn
# geraldton au
# odweyne so
# channel-port aux basques ca
# vaitupu wf
# college us
# ushuaia ar
# ayan ru
# esperance au
# cordoba ar
# stanislav ua
# hongjiang cn
# tayu id
# champasak la
# sergeyevka ru
# tual id
# bethel us
# prince rupert ca
# lolua tv
# mataura pf
# kavieng pg
# belushya guba ru
# albany au
# bredasdorp za
# mataura pf
# airai pw
# victoria sc
# iqaluit ca
# heishan cn
# saint-philippe re
# cape town za
# bulgan mn
# hilo us
# mys shmidta ru
# kazalinsk kz
# ponta do sol cv
# boralday kz
# gardhiwala in
# san ignacio bo
# busselton au
# jinxi cn
# yulara au
# rikitea pf
# butaritari ki
# itupiranga br
# akureyri is
# kapaa us
# cumberland us
# mansa in
# bredasdorp za
# amberley nz
# zlobin by
# punta arenas cl
# butaritari ki
# bethel us
# cape town za
# bilma ne
# bandarbeyla so
# kavieng pg
# ambilobe mg
# namibe ao
# bluff nz
# taltal cl
# pithora in
# koumac nc
# butaritari ki
# bengkulu id
# georgetown sh
# hilo us
# barrow us
# lorengau pg
# palabuhanratu id
# busselton au
# banda aceh id
# hobart au
# punta arenas cl
# khatanga ru
# mattru sl
# bargal so
# victoria sc
# coihaique cl
# port elizabeth za
# port hawkesbury ca
# hobart au
# severo-kurilsk ru
# puerto escondido mx
# smithers ca
# hilo us
# santa maria del oro mx
# hermanus za
# akhisar tr
# bambanglipuro id
# arraial do cabo br
# albany au
# new norfolk au
# busselton au
# albany au
# khatanga ru
# saint-pierre pm
# chernyshevskiy ru
# tasiilaq gl
# irtyshskiy ru
# ushuaia ar
# nantucket us
# busselton au
# flinders au
# ushuaia ar
# bluff nz
# jamestown sh
# hilo us
# tumannyy ru
# kongolo cd
# rikitea pf
# rikitea pf
# hermanus za
# capao da canoa br
# broken hill au
# bolungarvik is
# nyurba ru
# kapaa us
# georgetown sh
# busselton au
# codrington ag
# hithadhoo mv
# addi ugri er
# taolanaro mg
# butaritari ki
# dikson ru
# san patricio mx
# te anau nz
# fortuna us
# lebu cl
# itarema br
# alice springs au
# vaini to
# tiksi ru
# ushuaia ar
# airai pw
# shimoda jp
# samusu ws
# caramay ph
# creston ca
# castro cl
# new norfolk au
# bridgetown ca
# peniche pt
# cabo rojo us
# mataura pf
# seymchan ru
# busselton au
# busselton au
# provideniya ru
# nemuro jp
# puerto ayora ec
# vila vu
# cidreira br
# jamestown sh
# umzimvubu za
# taolanaro mg
# palu id
# saint george bm
# gigmoto ph
# carballo es
# albany au
# butaritari ki
# hithadhoo mv
# karratha au
# hobart au
# rikitea pf
# ushuaia ar
# albany au
# saldanha za
# ode ng
# jiayuguan cn
# victoria sc
# hobart au
# emerald au
# makakilo city us
# severnyy ru
# najran sa
# mandalgovi mn
# keetmanshoop na
# andros town bs
# ushuaia ar
# thompson ca
# ushuaia ar
# fortuna us
# lander us
# punta arenas cl
# laguna br
# carnarvon au
# segezha ru
# taksimo ru
# hobart au
# new norfolk au
# yellowknife ca
# teguldet ru
# rikitea pf
# buraydah sa

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 641

# %%
# Import the requests library.
import requests

# Import the API key.
from config import api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?APPID=" + api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?APPID=9f5d46bf6a7d704c75adb499630dd088

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?APPID=9f5d46bf6a7d704c75adb499630dd088&q=Boston

# %%
import requests
from config import api_key

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
city = "London"

# %%
query_url = url + "appid=" + api_key + "&q=" + city

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# %%
weather_json.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
weather_json.get("main")
# Out:
# {'temp': 281.01,
#  'feels_like': 277.38,
#  'temp_min': 280.37,
#  'temp_max': 281.48,
#  'pressure': 1010,
#  'humidity': 93}

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [401]>

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + api_key + "&q=" +"Boston" 
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?appid=9f5d46bf6a7d704c75adb499630dd088&q=Boston

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":600,"main":"Snow","description":"light snow","icon":"13n"},{"id":701,"main":"Mist","description":"mist","icon":"50n"}],"base":"stations","main":{"temp":271.58,"feels_like":267.09,"temp_min":270.93,"temp_max":272.59,"pressure":1015,"humidity":93},"visibility":6437,"wind":{"speed":3.09,"deg":10},"snow":{"1h":0.34},"clouds":{"all":90},"dt":1611714489,"sys":{"type":1,"id":3486,"country":"US","sunrise":1611662596,"sunset":1611697810},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 271.58,
#   'feels_like': 267.09,
#   'temp_min': 270.93,
#   'temp_max': 272.59,
#   'pressure': 1015,
#   'humidity': 93},
#  'visibility': 6437,
#  'wind': {'speed': 3.09, 'deg': 10},
#  'snow': {'1h': 0.34},
#  'clouds': {'all': 90},
#  'dt': 1611714489,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611662596,
#   'sunset': 1611697810},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + api_key + "&q=" + "Bston"


city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + api_key + "&q=" +"Boston" 
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'},
#   {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}],
#  'base': 'stations',
#  'main': {'temp': 271.58,
#   'feels_like': 267.09,
#   'temp_min': 270.93,
#   'temp_max': 272.59,
#   'pressure': 1015,
#   'humidity': 93},
#  'visibility': 6437,
#  'wind': {'speed': 3.09, 'deg': 10},
#  'snow': {'1h': 0.41},
#  'clouds': {'all': 90},
#  'dt': 1611714210,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611662596,
#   'sunset': 1611697810},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data["sys"]
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1611662596,
#  'sunset': 1611697810}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1611714210

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 272.59 93 90 3.09

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 1, 27, 2, 23, 30)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H: %M: %S')
# Out:
# '2021-01-27 02: 23: 30'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# # Create an empty list to hold the weather data.
# city_data = []
# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters.
# record_count = 1
# set_count = 1

# # Loop through all the cities in our list.
# # for i in range(len(cities)):

# #     # Group cities in sets of 50 for logging purposes.
# #     if (i % 50 == 0 and i >= 50):
# #         set_count += 1
# #         record_count += 1
# #     # Create endpoint URL with each city.
# #     city_url = url + "&q=" + cities[i]
    
# # Loop through all the cities in the list.
# for i, city in enumerate(cities):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count += 1
#     # Create endpoint URL with each city.
#     #city_url = url + "&q=" + city.replace(" ","+")
#     city_url = url + "appid=" + api_key + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}, {len(city_data)} Completed")
#     # Add 1 to the record count.
#     record_count += 1
    
#     # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         print(city_weather)
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    #city_url = url + "&q=" + city.replace(" ","+")
    city_url = url + "appid=" + api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | inta
# Processing Record 5 of Set 1 | polonnaruwa
# Processing Record 6 of Set 1 | aksarka
# Processing Record 7 of Set 1 | vostok
# Processing Record 8 of Set 1 | nanticoke
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | liverpool
# Processing Record 13 of Set 1 | makakilo city
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | belmonte
# Processing Record 16 of Set 1 | arona
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | korla
# Processing Record 19 of Set 1 | alice springs
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | opuwo
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | wajir
# Processing Record 29 of Set 1 | walvis bay
# Processing Record 30 of Set 1 | mukhen
# Processing Record 31 of Set 1 | razole
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | sicamous
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | lazarev
# Processing Record 39 of Set 1 | snasa
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | olafsvik
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | santana
# Processing Record 45 of Set 1 | axim
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | presidencia roque saenz pena
# Processing Record 48 of Set 1 | mwense
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | charters towers
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | saint-pierre
# Processing Record 8 of Set 2 | lata
# Processing Record 9 of Set 2 | coro
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | portoferraio
# Processing Record 14 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 2 | basco
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | taksimo
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | quarai
# Processing Record 21 of Set 2 | yangambi
# Processing Record 22 of Set 2 | owando
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | paamiut
# Processing Record 25 of Set 2 | banda aceh
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | broome
# Processing Record 29 of Set 2 | el alto
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | hualmay
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | siniscola
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | andenes
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | tiruvannamalai
# Processing Record 43 of Set 2 | reefton
# City not found. Skipping...
# Processing Record 44 of Set 2 | nioki
# Processing Record 45 of Set 2 | pattaya
# Processing Record 46 of Set 2 | emba
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | goderich
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | vanavara
# Processing Record 1 of Set 3 | blyznyuky
# Processing Record 2 of Set 3 | deniliquin
# Processing Record 3 of Set 3 | canitas
# City not found. Skipping...
# Processing Record 4 of Set 3 | sao felix do xingu
# Processing Record 5 of Set 3 | hovd
# Processing Record 6 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 3 | wuwei
# Processing Record 8 of Set 3 | mayumba
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | chapais
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | brighton
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | varhaug
# Processing Record 19 of Set 3 | tsiroanomandidy
# Processing Record 20 of Set 3 | ulaanbaatar
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | tarauaca
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | quang ngai
# Processing Record 26 of Set 3 | nelson bay
# Processing Record 27 of Set 3 | svetlogorsk
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | baiquan
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | poronaysk
# Processing Record 33 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 34 of Set 3 | mnogovershinnyy
# Processing Record 35 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | meadow lake
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | shihezi
# Processing Record 41 of Set 3 | athabasca
# Processing Record 42 of Set 3 | nkhotakota
# Processing Record 43 of Set 3 | yakeshi
# Processing Record 44 of Set 3 | hobart
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | voi
# Processing Record 47 of Set 3 | flin flon
# Processing Record 48 of Set 3 | tommot
# Processing Record 49 of Set 3 | lorengau
# Processing Record 50 of Set 3 | moerai
# Processing Record 1 of Set 4 | bakloh
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | kalinovskaya
# Processing Record 4 of Set 4 | tual
# Processing Record 5 of Set 4 | kangaatsiaq
# Processing Record 6 of Set 4 | adrar
# Processing Record 7 of Set 4 | grindavik
# Processing Record 8 of Set 4 | lipari
# Processing Record 9 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 4 | yining
# Processing Record 11 of Set 4 | pasaje
# Processing Record 12 of Set 4 | santa isabel
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | sambava
# Processing Record 15 of Set 4 | kamaishi
# Processing Record 16 of Set 4 | shalya
# Processing Record 17 of Set 4 | stepnyak
# Processing Record 18 of Set 4 | inhambane
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | novikovo
# Processing Record 21 of Set 4 | yar-sale
# Processing Record 22 of Set 4 | belaya gora
# Processing Record 23 of Set 4 | northam
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | alto araguaia
# Processing Record 26 of Set 4 | upata
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | praia
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | roald
# Processing Record 32 of Set 4 | mitu
# Processing Record 33 of Set 4 | gornozavodsk
# Processing Record 34 of Set 4 | maniitsoq
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | el tigre
# Processing Record 37 of Set 4 | leningradskiy
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | shimoda
# Processing Record 40 of Set 4 | alihe
# Processing Record 41 of Set 4 | santo tomas
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | port-gentil
# Processing Record 46 of Set 4 | bay roberts
# Processing Record 47 of Set 4 | fairlie
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | cayenne
# Processing Record 50 of Set 4 | monrovia
# Processing Record 1 of Set 5 | richards bay
# Processing Record 2 of Set 5 | kirakira
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | pisco
# Processing Record 6 of Set 5 | marzuq
# Processing Record 7 of Set 5 | yerofey pavlovich
# Processing Record 8 of Set 5 | albertville
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | kindu
# Processing Record 12 of Set 5 | poum
# Processing Record 13 of Set 5 | januaria
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | nuuk
# Processing Record 16 of Set 5 | saint-joseph
# Processing Record 17 of Set 5 | elko
# Processing Record 18 of Set 5 | rio grande
# Processing Record 19 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 5 | bilibino
# Processing Record 21 of Set 5 | raboso
# Processing Record 22 of Set 5 | coihaique
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | vestmanna
# Processing Record 27 of Set 5 | urubicha
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | olga
# Processing Record 30 of Set 5 | kupang
# Processing Record 31 of Set 5 | itoman
# Processing Record 32 of Set 5 | kidal
# Processing Record 33 of Set 5 | montepuez
# Processing Record 34 of Set 5 | saurimo
# Processing Record 35 of Set 5 | vestmannaeyjar
# Processing Record 36 of Set 5 | gobabis
# Processing Record 37 of Set 5 | tura
# Processing Record 38 of Set 5 | talnakh
# Processing Record 39 of Set 5 | marrakesh
# Processing Record 40 of Set 5 | topolobampo
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | ulaangom
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | sibolga
# Processing Record 45 of Set 5 | devyatka
# City not found. Skipping...
# Processing Record 46 of Set 5 | soyo
# Processing Record 47 of Set 5 | bozoum
# Processing Record 48 of Set 5 | jumla
# Processing Record 49 of Set 5 | upernavik
# Processing Record 50 of Set 5 | new waterford
# Processing Record 1 of Set 6 | faanui
# Processing Record 2 of Set 6 | sao filipe
# Processing Record 3 of Set 6 | busselton
# Processing Record 4 of Set 6 | bakchar
# Processing Record 5 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 6 | bowen
# Processing Record 7 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 6 | aswan
# Processing Record 9 of Set 6 | komsomolskiy
# Processing Record 10 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 11 of Set 6 | neryungri
# Processing Record 12 of Set 6 | pevek
# Processing Record 13 of Set 6 | bayburt
# Processing Record 14 of Set 6 | mattoon
# Processing Record 15 of Set 6 | hamilton
# Processing Record 16 of Set 6 | pampierstad
# Processing Record 17 of Set 6 | arlit
# Processing Record 18 of Set 6 | mogadishu
# Processing Record 19 of Set 6 | roxana
# Processing Record 20 of Set 6 | belyy yar
# Processing Record 21 of Set 6 | singarayakonda
# Processing Record 22 of Set 6 | abu samrah
# Processing Record 23 of Set 6 | neiafu
# Processing Record 24 of Set 6 | vinga
# Processing Record 25 of Set 6 | maun
# Processing Record 26 of Set 6 | raudeberg
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | mehamn
# Processing Record 29 of Set 6 | oranjemund
# Processing Record 30 of Set 6 | ekhabi
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | chalon-sur-saone
# Processing Record 33 of Set 6 | kulhudhuffushi
# Processing Record 34 of Set 6 | verkhnevilyuysk
# Processing Record 35 of Set 6 | nemuro
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | usinsk
# Processing Record 38 of Set 6 | olinda
# Processing Record 39 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 6 | zhangjiakou
# Processing Record 41 of Set 6 | baykit
# Processing Record 42 of Set 6 | hofn
# Processing Record 43 of Set 6 | ipora
# Processing Record 44 of Set 6 | port elizabeth
# Processing Record 45 of Set 6 | murgab
# Processing Record 46 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 6 | leh
# Processing Record 48 of Set 6 | ilulissat
# Processing Record 49 of Set 6 | bachaquero
# Processing Record 50 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 1 of Set 7 | formosa
# Processing Record 2 of Set 7 | wharton
# Processing Record 3 of Set 7 | carutapera
# Processing Record 4 of Set 7 | senneterre
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | sucre
# Processing Record 7 of Set 7 | blagoyevo
# Processing Record 8 of Set 7 | toora-khem
# Processing Record 9 of Set 7 | mizdah
# Processing Record 10 of Set 7 | konotop
# Processing Record 11 of Set 7 | bereznehuvate
# Processing Record 12 of Set 7 | bijawar
# Processing Record 13 of Set 7 | santos reyes nopala
# Processing Record 14 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | port hardy
# Processing Record 17 of Set 7 | padang
# Processing Record 18 of Set 7 | severo-kurilsk
# Processing Record 19 of Set 7 | geri
# Processing Record 20 of Set 7 | yithion
# City not found. Skipping...
# Processing Record 21 of Set 7 | ordynskoye
# Processing Record 22 of Set 7 | namibe
# Processing Record 23 of Set 7 | manzhouli
# Processing Record 24 of Set 7 | los llanos de aridane
# Processing Record 25 of Set 7 | fuyang
# Processing Record 26 of Set 7 | tyup
# Processing Record 27 of Set 7 | coquimbo
# Processing Record 28 of Set 7 | balagansk
# Processing Record 29 of Set 7 | broken hill
# Processing Record 30 of Set 7 | ballina
# Processing Record 31 of Set 7 | ostrovnoy
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | san patricio
# Processing Record 34 of Set 7 | maragogi
# Processing Record 35 of Set 7 | verkh-usugli
# Processing Record 36 of Set 7 | nirmal
# Processing Record 37 of Set 7 | mahajanga
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | savannah bight
# Processing Record 40 of Set 7 | nome
# Processing Record 41 of Set 7 | sayalgudi
# City not found. Skipping...
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | touba
# Processing Record 44 of Set 7 | mayor pablo lagerenza
# Processing Record 45 of Set 7 | saint-georges
# Processing Record 46 of Set 7 | alikalia
# Processing Record 47 of Set 7 | port hedland
# Processing Record 48 of Set 7 | shuangyang
# Processing Record 49 of Set 7 | severnoye
# Processing Record 50 of Set 7 | vardo
# Processing Record 1 of Set 8 | dahegam
# Processing Record 2 of Set 8 | kutum
# Processing Record 3 of Set 8 | juneau
# Processing Record 4 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 8 | eureka
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | apache junction
# Processing Record 8 of Set 8 | skelleftea
# Processing Record 9 of Set 8 | coroico
# Processing Record 10 of Set 8 | te anau
# Processing Record 11 of Set 8 | livingston
# Processing Record 12 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 8 | lima
# Processing Record 14 of Set 8 | umm kaddadah
# Processing Record 15 of Set 8 | majene
# Processing Record 16 of Set 8 | hailar
# Processing Record 17 of Set 8 | grindsted
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | lakselv
# Processing Record 20 of Set 8 | antalaha
# Processing Record 21 of Set 8 | casma
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | atherton
# Processing Record 24 of Set 8 | dunedin
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 8 | salinas
# Processing Record 28 of Set 8 | kieta
# Processing Record 29 of Set 8 | ponta do sol
# Processing Record 30 of Set 8 | kabalo
# Processing Record 31 of Set 8 | stornoway
# Processing Record 32 of Set 8 | flinders
# Processing Record 33 of Set 8 | sharjah
# Processing Record 34 of Set 8 | asau
# Processing Record 35 of Set 8 | alpena
# Processing Record 36 of Set 8 | mvuma
# Processing Record 37 of Set 8 | waremme
# Processing Record 38 of Set 8 | annau
# Processing Record 39 of Set 8 | voka
# Processing Record 40 of Set 8 | snezhnogorsk
# Processing Record 41 of Set 8 | tazovskiy
# Processing Record 42 of Set 8 | garm
# City not found. Skipping...
# Processing Record 43 of Set 8 | kikwit
# Processing Record 44 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 8 | hai duong
# Processing Record 46 of Set 8 | koshurnikovo
# Processing Record 47 of Set 8 | sao miguel do araguaia
# Processing Record 48 of Set 8 | kijabe
# Processing Record 49 of Set 8 | vitim
# Processing Record 50 of Set 8 | kitimat
# Processing Record 1 of Set 9 | jhinjhak
# Processing Record 2 of Set 9 | inirida
# Processing Record 3 of Set 9 | tahta
# Processing Record 4 of Set 9 | la ronge
# Processing Record 5 of Set 9 | homer
# Processing Record 6 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 9 | dimapur
# Processing Record 8 of Set 9 | berlevag
# Processing Record 9 of Set 9 | port augusta
# Processing Record 10 of Set 9 | moranbah
# Processing Record 11 of Set 9 | takoradi
# Processing Record 12 of Set 9 | marsh harbour
# Processing Record 13 of Set 9 | erzin
# Processing Record 14 of Set 9 | waipawa
# Processing Record 15 of Set 9 | bardiyah
# Processing Record 16 of Set 9 | qasigiannguit
# Processing Record 17 of Set 9 | vilhena
# Processing Record 18 of Set 9 | brejinho
# Processing Record 19 of Set 9 | manaure
# Processing Record 20 of Set 9 | nova olinda do norte
# Processing Record 21 of Set 9 | lagoa
# Processing Record 22 of Set 9 | cidreira
# Processing Record 23 of Set 9 | kaga
# Processing Record 24 of Set 9 | sokoni
# Processing Record 25 of Set 9 | lithakia
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | galveston
# Processing Record 28 of Set 9 | spassk
# Processing Record 29 of Set 9 | challapata
# Processing Record 30 of Set 9 | voyinka
# Processing Record 31 of Set 9 | branistea
# Processing Record 32 of Set 9 | zhiryatino
# Processing Record 33 of Set 9 | kijang
# Processing Record 34 of Set 9 | saryg-sep
# Processing Record 35 of Set 9 | plettenberg bay
# Processing Record 36 of Set 9 | cambridge
# Processing Record 37 of Set 9 | arica
# Processing Record 38 of Set 9 | samarai
# Processing Record 39 of Set 9 | nyurba
# Processing Record 40 of Set 9 | malindi
# Processing Record 41 of Set 9 | geraldton
# Processing Record 42 of Set 9 | gamba
# Processing Record 43 of Set 9 | tandalti
# Processing Record 44 of Set 9 | victoria
# Processing Record 45 of Set 9 | kuala terengganu
# Processing Record 46 of Set 9 | verkhnyaya salda
# Processing Record 47 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 48 of Set 9 | izvestkovyy
# Processing Record 49 of Set 9 | barra da estiva
# Processing Record 50 of Set 9 | morondava
# Processing Record 1 of Set 10 | neutraubling
# Processing Record 2 of Set 10 | sukkur
# Processing Record 3 of Set 10 | teya
# Processing Record 4 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 10 | valera
# Processing Record 6 of Set 10 | devonport
# Processing Record 7 of Set 10 | vysokogornyy
# Processing Record 8 of Set 10 | youghal
# Processing Record 9 of Set 10 | forssa
# Processing Record 10 of Set 10 | olot
# Processing Record 11 of Set 10 | blenheim
# Processing Record 12 of Set 10 | chunskiy
# Processing Record 13 of Set 10 | batie
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | kilindoni
# Processing Record 16 of Set 10 | payakumbuh
# Processing Record 17 of Set 10 | puerto del rosario
# Processing Record 18 of Set 10 | nouadhibou
# Processing Record 19 of Set 10 | tsuruga
# Processing Record 20 of Set 10 | rodrigues alves
# Processing Record 21 of Set 10 | port-cartier
# Processing Record 22 of Set 10 | shibarghan
# City not found. Skipping...
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | villa oliva
# City not found. Skipping...
# Processing Record 25 of Set 10 | isla mujeres
# Processing Record 26 of Set 10 | north myrtle beach
# Processing Record 27 of Set 10 | veraval
# Processing Record 28 of Set 10 | kholodnyy
# Processing Record 29 of Set 10 | zakamensk
# Processing Record 30 of Set 10 | becerril
# Processing Record 31 of Set 10 | ayagoz
# Processing Record 32 of Set 10 | dingle
# Processing Record 33 of Set 10 | talakan
# Processing Record 34 of Set 10 | shelby
# Processing Record 35 of Set 10 | bathsheba
# Processing Record 36 of Set 10 | san agustin acasaguastlan
# Processing Record 37 of Set 10 | celestun
# Processing Record 38 of Set 10 | ulcinj
# Processing Record 39 of Set 10 | borgo san lorenzo
# Processing Record 40 of Set 10 | marsa matruh
# Processing Record 41 of Set 10 | ponta delgada
# Processing Record 42 of Set 10 | san antonio
# Processing Record 43 of Set 10 | duobao
# Processing Record 44 of Set 10 | cabinda
# Processing Record 45 of Set 10 | ternate
# Processing Record 46 of Set 10 | polovinnoye
# Processing Record 47 of Set 10 | oktyabrskoye
# Processing Record 48 of Set 10 | tomatlan
# Processing Record 49 of Set 10 | alofi
# Processing Record 50 of Set 10 | montelibano
# Processing Record 1 of Set 11 | neka
# Processing Record 2 of Set 11 | sao joao da barra
# Processing Record 3 of Set 11 | touros
# Processing Record 4 of Set 11 | general roca
# Processing Record 5 of Set 11 | bestobe
# Processing Record 6 of Set 11 | karratha
# Processing Record 7 of Set 11 | bahia honda
# Processing Record 8 of Set 11 | susehri
# Processing Record 9 of Set 11 | christchurch
# Processing Record 10 of Set 11 | husavik
# Processing Record 11 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 11 | necochea
# Processing Record 13 of Set 11 | jabinyanah
# Processing Record 14 of Set 11 | faya
# Processing Record 15 of Set 11 | den helder
# Processing Record 16 of Set 11 | la palma
# Processing Record 17 of Set 11 | praia da vitoria
# Processing Record 18 of Set 11 | itupiranga
# Processing Record 19 of Set 11 | mananjary
# Processing Record 20 of Set 11 | luganville
# Processing Record 21 of Set 11 | comodoro rivadavia
# Processing Record 22 of Set 11 | westport
# Processing Record 23 of Set 11 | kuytun
# Processing Record 24 of Set 11 | isla vista
# Processing Record 25 of Set 11 | calabozo
# Processing Record 26 of Set 11 | portland
# Processing Record 27 of Set 11 | muravlenko
# Processing Record 28 of Set 11 | ramsgate
# Processing Record 29 of Set 11 | santa vitoria do palmar
# Processing Record 30 of Set 11 | winneba
# Processing Record 31 of Set 11 | impfondo
# Processing Record 32 of Set 11 | ugoofaaru
# Processing Record 33 of Set 11 | puerto gaitan
# Processing Record 34 of Set 11 | safaga
# Processing Record 35 of Set 11 | salalah
# Processing Record 36 of Set 11 | scarborough
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | marabba
# Processing Record 39 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | tripoli
# Processing Record 41 of Set 11 | bandarbeyla
# Processing Record 42 of Set 11 | pangai
# Processing Record 43 of Set 11 | bartica
# Processing Record 44 of Set 11 | naugarzan
# City not found. Skipping...
# Processing Record 45 of Set 11 | marienburg
# Processing Record 46 of Set 11 | souillac
# Processing Record 47 of Set 11 | jasper
# Processing Record 48 of Set 11 | mahebourg
# Processing Record 49 of Set 11 | santa rosa del sur
# Processing Record 50 of Set 11 | hvide sande
# Processing Record 1 of Set 12 | lienz
# Processing Record 2 of Set 12 | hobyo
# Processing Record 3 of Set 12 | fairbanks
# Processing Record 4 of Set 12 | horana
# Processing Record 5 of Set 12 | kollegal
# Processing Record 6 of Set 12 | salinopolis
# Processing Record 7 of Set 12 | methoni
# Processing Record 8 of Set 12 | bar-le-duc
# Processing Record 9 of Set 12 | carauari
# Processing Record 10 of Set 12 | qiongshan
# Processing Record 11 of Set 12 | porto novo
# Processing Record 12 of Set 12 | north bend
# Processing Record 13 of Set 12 | mount gambier
# Processing Record 14 of Set 12 | sayat
# Processing Record 15 of Set 12 | mitsamiouli
# Processing Record 16 of Set 12 | trapani
# Processing Record 17 of Set 12 | mae sai
# Processing Record 18 of Set 12 | narsaq
# Processing Record 19 of Set 12 | beloha
# Processing Record 20 of Set 12 | halifax
# Processing Record 21 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 12 | lao cai
# Processing Record 23 of Set 12 | odweyne
# Processing Record 24 of Set 12 | channel-port aux basques
# Processing Record 25 of Set 12 | ayan
# Processing Record 26 of Set 12 | cordoba
# Processing Record 27 of Set 12 | stanislav
# Processing Record 28 of Set 12 | hongjiang
# Processing Record 29 of Set 12 | tayu
# Processing Record 30 of Set 12 | champasak
# Processing Record 31 of Set 12 | sergeyevka
# Processing Record 32 of Set 12 | prince rupert
# Processing Record 33 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 12 | heishan
# Processing Record 35 of Set 12 | bulgan
# Processing Record 36 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 12 | boralday
# Processing Record 38 of Set 12 | gardhiwala
# City not found. Skipping...
# Processing Record 39 of Set 12 | san ignacio
# Processing Record 40 of Set 12 | jinxi
# Processing Record 41 of Set 12 | yulara
# Processing Record 42 of Set 12 | akureyri
# Processing Record 43 of Set 12 | cumberland
# Processing Record 44 of Set 12 | mansa
# Processing Record 45 of Set 12 | amberley
# Processing Record 46 of Set 12 | zlobin
# Processing Record 47 of Set 12 | bilma
# Processing Record 48 of Set 12 | ambilobe
# Processing Record 49 of Set 12 | pithora
# Processing Record 50 of Set 12 | koumac
# Processing Record 1 of Set 13 | bengkulu
# Processing Record 2 of Set 13 | mattru
# Processing Record 3 of Set 13 | port hawkesbury
# Processing Record 4 of Set 13 | puerto escondido
# Processing Record 5 of Set 13 | smithers
# Processing Record 6 of Set 13 | santa maria del oro
# Processing Record 7 of Set 13 | akhisar
# Processing Record 8 of Set 13 | bambanglipuro
# Processing Record 9 of Set 13 | chernyshevskiy
# Processing Record 10 of Set 13 | irtyshskiy
# Processing Record 11 of Set 13 | nantucket
# Processing Record 12 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 13 | kongolo
# Processing Record 14 of Set 13 | capao da canoa
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 17 of Set 13 | itarema
# Processing Record 18 of Set 13 | caramay
# Processing Record 19 of Set 13 | creston
# Processing Record 20 of Set 13 | bridgetown
# Processing Record 21 of Set 13 | peniche
# Processing Record 22 of Set 13 | cabo rojo
# Processing Record 23 of Set 13 | seymchan
# Processing Record 24 of Set 13 | vila
# Processing Record 25 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 13 | palu
# Processing Record 27 of Set 13 | saint george
# Processing Record 28 of Set 13 | gigmoto
# Processing Record 29 of Set 13 | carballo
# Processing Record 30 of Set 13 | ode
# Processing Record 31 of Set 13 | jiayuguan
# Processing Record 32 of Set 13 | emerald
# Processing Record 33 of Set 13 | severnyy
# Processing Record 34 of Set 13 | najran
# Processing Record 35 of Set 13 | mandalgovi
# Processing Record 36 of Set 13 | keetmanshoop
# Processing Record 37 of Set 13 | andros town
# Processing Record 38 of Set 13 | lander
# Processing Record 39 of Set 13 | segezha
# Processing Record 40 of Set 13 | teguldet
# Processing Record 41 of Set 13 | buraydah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 289.82,
#   'Humidity': 94,
#   'Cloudiness': 76,
#   'Wind Speed': 1.51,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:48:51'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 298.15,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 12.86,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:44:28'},
#  {'City': 'Inta',
#   'Lat': 66.0317,
#   'Lng': 60.1659,
#   'Max Temp': 243.21,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:48:52'},
#  {'City': 'Polonnaruwa',
#   'Lat': 7.9333,
#   'Lng': 81,
#   'Max Temp': 296.95,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 0.64,
#   'Country': 'LK',
#   'Date': '2021-01-27 02:48:52'},
#  {'City': 'Aksarka',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': 236.69,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:45:23'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 258.98,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 5.57,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:45:35'},
#  {'City': 'Nanticoke',
#   'Lat': 41.2054,
#   'Lng': -76.0049,
#   'Max Temp': 273.15,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:53'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 292.59,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:45:03'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 270.93,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.02,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:53'},
#  {'City': 'Liverpool',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 282.15,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'GB',
#   'Date': '2021-01-27 02:48:31'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 300.15,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:54'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 237.11,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 1.08,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:48:54'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 299.15,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:48:54'},
#  {'City': 'Arona',
#   'Lat': 28.0996,
#   'Lng': -16.681,
#   'Max Temp': 290.15,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'ES',
#   'Date': '2021-01-27 02:48:54'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 289.82,
#   'Humidity': 45,
#   'Cloudiness': 99,
#   'Wind Speed': 0.89,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:44:16'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 268.67,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 0.82,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:46:20'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 307.04,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:46:54'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 292.59,
#   'Humidity': 77,
#   'Cloudiness': 89,
#   'Wind Speed': 4.92,
#   'Country': 'NZ',
#   'Date': '2021-01-27 02:48:55'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 279.15,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'CL',
#   'Date': '2021-01-27 02:48:56'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 300.57,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 4.2,
#   'Country': 'KI',
#   'Date': '2021-01-27 02:48:56'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 297.59,
#   'Humidity': 95,
#   'Cloudiness': 38,
#   'Wind Speed': 2.68,
#   'Country': 'EC',
#   'Date': '2021-01-27 02:48:56'},
#  {'City': 'Opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 292.4,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 0.18,
#   'Country': 'NA',
#   'Date': '2021-01-27 02:48:56'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 276.15,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': '2021-01-27 02:44:48'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 270.37,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:15'},
#  {'City': 'Wajir',
#   'Lat': 1.7471,
#   'Lng': 40.0573,
#   'Max Temp': 295.64,
#   'Humidity': 76,
#   'Cloudiness': 13,
#   'Wind Speed': 5.08,
#   'Country': 'KE',
#   'Date': '2021-01-27 02:48:57'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 293.15,
#   'Humidity': 88,
#   'Cloudiness': 16,
#   'Wind Speed': 1.54,
#   'Country': 'NA',
#   'Date': '2021-01-27 02:48:57'},
#  {'City': 'Mukhen',
#   'Lat': 48.1,
#   'Lng': 136.1,
#   'Max Temp': 257.64,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.49,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:48:57'},
#  {'City': 'Razole',
#   'Lat': 16.4833,
#   'Lng': 81.8333,
#   'Max Temp': 295.15,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:48:57'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 234.62,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.47,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:45:20'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 252.58,
#   'Humidity': 87,
#   'Cloudiness': 72,
#   'Wind Speed': 1.81,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:44:25'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 272.59,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.43,
#   'Country': 'US',
#   'Date': '2021-01-27 02:45:34'},
#  {'City': 'Sicamous',
#   'Lat': 50.8331,
#   'Lng': -118.9856,
#   'Max Temp': 272.15,
#   'Humidity': 80,
#   'Cloudiness': 63,
#   'Wind Speed': 1.81,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:45:11'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 292.59,
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 4.92,
#   'Country': 'NZ',
#   'Date': '2021-01-27 02:48:59'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 242.66,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:48:59'},
#  {'City': 'Lazarev',
#   'Lat': 52.225,
#   'Lng': 141.5131,
#   'Max Temp': 256.35,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.12,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:48:59'},
#  {'City': 'Snasa',
#   'Lat': 64.2457,
#   'Lng': 12.3778,
#   'Max Temp': 268.75,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.78,
#   'Country': 'NO',
#   'Date': '2021-01-27 02:48:59'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 270.47,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.41,
#   'Country': 'IS',
#   'Date': '2021-01-27 02:49:00'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 257.15,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 11.32,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:00'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 245.15,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': '2021-01-27 02:47:46'},
#  {'City': 'Santana',
#   'Lat': -0.0583,
#   'Lng': -51.1817,
#   'Max Temp': 297.15,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:00'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 298.48,
#   'Humidity': 88,
#   'Cloudiness': 79,
#   'Wind Speed': 2.23,
#   'Country': 'GH',
#   'Date': '2021-01-27 02:49:01'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 235.61,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 0.95,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:01'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 298.71,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 0.89,
#   'Country': 'AR',
#   'Date': '2021-01-27 02:49:01'},
#  {'City': 'Mwense',
#   'Lat': -10.3845,
#   'Lng': 28.698,
#   'Max Temp': 291.95,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.9,
#   'Country': 'ZM',
#   'Date': '2021-01-27 02:49:01'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 273.71,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.23,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:02'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 252.59,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:02'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 297.59,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:02'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 296.49,
#   'Humidity': 87,
#   'Cloudiness': 52,
#   'Wind Speed': 1.83,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:47:13'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 305.83,
#   'Humidity': 40,
#   'Cloudiness': 12,
#   'Wind Speed': 5.45,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:02'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 277.15,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 10.8,
#   'Country': 'AR',
#   'Date': '2021-01-27 02:49:03'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 299.93,
#   'Humidity': 74,
#   'Cloudiness': 10,
#   'Wind Speed': 4.65,
#   'Country': 'PF',
#   'Date': '2021-01-27 02:47:14'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 295.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Country': 'UY',
#   'Date': '2021-01-27 02:49:03'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 298.15,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'RE',
#   'Date': '2021-01-27 02:49:03'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 287.59,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 0.83,
#   'Country': 'PT',
#   'Date': '2021-01-27 02:49:04'},
#  {'City': 'Coro',
#   'Lat': 11.4045,
#   'Lng': -69.6734,
#   'Max Temp': 297.09,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 6.47,
#   'Country': 'VE',
#   'Date': '2021-01-27 02:49:04'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 283.15,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 1.86,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:34'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 246.41,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 3.05,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:04'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 260.15,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 5,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:44:10'},
#  {'City': 'Portoferraio',
#   'Lat': 42.8115,
#   'Lng': 10.3146,
#   'Max Temp': 272.15,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'IT',
#   'Date': '2021-01-27 02:49:05'},
#  {'City': 'Basco',
#   'Lat': 20.4487,
#   'Lng': 121.9702,
#   'Max Temp': 295.76,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 7.7,
#   'Country': 'PH',
#   'Date': '2021-01-27 02:49:05'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 261.29,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.85,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:06'},
#  {'City': 'Taksimo',
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': 246.96,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.29,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:06'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 303.15,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': '2021-01-27 02:49:06'},
#  {'City': 'Quarai',
#   'Lat': -30.3875,
#   'Lng': -56.4514,
#   'Max Temp': 295.98,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:45:29'},
#  {'City': 'Yangambi',
#   'Lat': 0.8102,
#   'Lng': 24.4336,
#   'Max Temp': 294.24,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.22,
#   'Country': 'CD',
#   'Date': '2021-01-27 02:49:06'},
#  {'City': 'Owando',
#   'Lat': -0.4819,
#   'Lng': 15.8999,
#   'Max Temp': 294.84,
#   'Humidity': 94,
#   'Cloudiness': 64,
#   'Wind Speed': 1.85,
#   'Country': 'CG',
#   'Date': '2021-01-27 02:45:05'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 283.15,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'JP',
#   'Date': '2021-01-27 02:49:07'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 263.52,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 3.97,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:07'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 301.33,
#   'Humidity': 67,
#   'Cloudiness': 77,
#   'Wind Speed': 2.78,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:49:07'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 291.11,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.65,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:08'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 272.04,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': '2021-01-27 02:44:27'},
#  {'City': 'El Alto',
#   'Lat': -4.2714,
#   'Lng': -81.2147,
#   'Max Temp': 296.84,
#   'Humidity': 72,
#   'Cloudiness': 79,
#   'Wind Speed': 6.44,
#   'Country': 'PE',
#   'Date': '2021-01-27 02:49:08'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 298.94,
#   'Humidity': 79,
#   'Cloudiness': 3,
#   'Wind Speed': 8.15,
#   'Country': 'PF',
#   'Date': '2021-01-27 02:49:08'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 294.83,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.87,
#   'Country': 'PE',
#   'Date': '2021-01-27 02:49:09'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 292.59,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Country': 'NZ',
#   'Date': '2021-01-27 02:49:09'},
#  {'City': 'Siniscola',
#   'Lat': 40.5719,
#   'Lng': 9.6922,
#   'Max Temp': 280.15,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'IT',
#   'Date': '2021-01-27 02:49:09'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 273.15,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': '2021-01-27 02:44:22'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 294.15,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'AR',
#   'Date': '2021-01-27 02:49:10'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 263.73,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.7,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:10'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 291.36,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 11.41,
#   'Country': 'NA',
#   'Date': '2021-01-27 02:45:21'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 300.15,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'TO',
#   'Date': '2021-01-27 02:49:10'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 270.15,
#   'Humidity': 74,
#   'Cloudiness': 69,
#   'Wind Speed': 4.63,
#   'Country': 'NO',
#   'Date': '2021-01-27 02:49:11'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 300.46,
#   'Humidity': 77,
#   'Cloudiness': 87,
#   'Wind Speed': 5.82,
#   'Country': 'MV',
#   'Date': '2021-01-27 02:49:11'},
#  {'City': 'Tiruvannamalai',
#   'Lat': 12.2167,
#   'Lng': 79.0667,
#   'Max Temp': 295.15,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 1.84,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:49:11'},
#  {'City': 'Nioki',
#   'Lat': -2.7167,
#   'Lng': 17.6833,
#   'Max Temp': 294.76,
#   'Humidity': 98,
#   'Cloudiness': 80,
#   'Wind Speed': 1.2,
#   'Country': 'CD',
#   'Date': '2021-01-27 02:49:12'},
#  {'City': 'Pattaya',
#   'Lat': 12.9333,
#   'Lng': 100.8833,
#   'Max Temp': 305.37,
#   'Humidity': 65,
#   'Cloudiness': 24,
#   'Wind Speed': 1.93,
#   'Country': 'TH',
#   'Date': '2021-01-27 02:48:04'},
#  {'City': 'Emba',
#   'Lat': 48.8264,
#   'Lng': 58.1442,
#   'Max Temp': 263.62,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'KZ',
#   'Date': '2021-01-27 02:49:12'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 285.24,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 3.91,
#   'Country': 'CL',
#   'Date': '2021-01-27 02:49:12'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 269.15,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:45:41'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 298.15,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:13'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 232.93,
#   'Humidity': 80,
#   'Cloudiness': 35,
#   'Wind Speed': 1.09,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:13'},
#  {'City': 'Blyznyuky',
#   'Lat': 48.8578,
#   'Lng': 36.5551,
#   'Max Temp': 277.65,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.01,
#   'Country': 'UA',
#   'Date': '2021-01-27 02:49:13'},
#  {'City': 'Deniliquin',
#   'Lat': -35.5333,
#   'Lng': 144.9667,
#   'Max Temp': 299.26,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 0.45,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:13'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 296.11,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.52,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:14'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 255.19,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 0.56,
#   'Country': 'MN',
#   'Date': '2021-01-27 02:49:14'},
#  {'City': 'Wuwei',
#   'Lat': 37.9281,
#   'Lng': 102.6414,
#   'Max Temp': 269.44,
#   'Humidity': 74,
#   'Cloudiness': 37,
#   'Wind Speed': 1.17,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:49:14'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 298.25,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 2.31,
#   'Country': 'GA',
#   'Date': '2021-01-27 02:49:15'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 264.15,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:45:52'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 299.82,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'MU',
#   'Date': '2021-01-27 02:49:16'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 249.82,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:16'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 290.37,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.77,
#   'Country': 'PT',
#   'Date': '2021-01-27 02:49:16'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 274.26,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:16'},
#  {'City': 'Brighton',
#   'Lat': 50.8284,
#   'Lng': -0.1395,
#   'Max Temp': 280.93,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'GB',
#   'Date': '2021-01-27 02:37:47'},
#  {'City': 'Varhaug',
#   'Lat': 58.6147,
#   'Lng': 5.6457,
#   'Max Temp': 268.71,
#   'Humidity': 93,
#   'Cloudiness': 16,
#   'Wind Speed': 1.03,
#   'Country': 'NO',
#   'Date': '2021-01-27 02:49:17'},
#  {'City': 'Tsiroanomandidy',
#   'Lat': -18.7667,
#   'Lng': 46.0333,
#   'Max Temp': 292.64,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 0.05,
#   'Country': 'MG',
#   'Date': '2021-01-27 02:49:17'},
#  {'City': 'Ulaanbaatar',
#   'Lat': 47.9077,
#   'Lng': 106.8832,
#   'Max Temp': 242.15,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 1,
#   'Country': 'MN',
#   'Date': '2021-01-27 02:49:17'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 247.15,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 1.65,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:18'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 299.15,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:18'},
#  {'City': 'Tarauaca',
#   'Lat': -8.1614,
#   'Lng': -70.7656,
#   'Max Temp': 296.03,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.69,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:47:56'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 292.59,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:49:18'},
#  {'City': 'Quang Ngai',
#   'Lat': 15.1167,
#   'Lng': 108.8,
#   'Max Temp': 297.18,
#   'Humidity': 75,
#   'Cloudiness': 54,
#   'Wind Speed': 2.11,
#   'Country': 'VN',
#   'Date': '2021-01-27 02:49:18'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 295.37,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.23,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:19'},
#  {'City': 'Svetlogorsk',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 272.37,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 7.97,
#   'Country': 'BY',
#   'Date': '2021-01-27 02:49:19'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 241.11,
#   'Humidity': 81,
#   'Cloudiness': 34,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:19'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 286.63,
#   'Humidity': 78,
#   'Cloudiness': 46,
#   'Wind Speed': 7.34,
#   'Country': 'CL',
#   'Date': '2021-01-27 02:49:19'},
#  {'City': 'Baiquan',
#   'Lat': 47.5833,
#   'Lng': 126.0833,
#   'Max Temp': 255.1,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.72,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:49:20'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 294.26,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 3.37,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:45:15'},
#  {'City': 'Poronaysk',
#   'Lat': 49.2167,
#   'Lng': 143.1167,
#   'Max Temp': 260.9,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:48:13'},
#  {'City': 'Mnogovershinnyy',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': 250.9,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:20'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 290.12,
#   'Humidity': 82,
#   'Cloudiness': 60,
#   'Wind Speed': 14.46,
#   'Country': 'PT',
#   'Date': '2021-01-27 02:49:21'},
#  {'City': 'Meadow Lake',
#   'Lat': 34.8014,
#   'Lng': -106.5436,
#   'Max Temp': 272.59,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:21'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 270.15,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:21'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 296.55,
#   'Humidity': 66,
#   'Cloudiness': 96,
#   'Wind Speed': 2.08,
#   'Country': 'TL',
#   'Date': '2021-01-27 02:45:14'},
#  {'City': 'Shihezi',
#   'Lat': 44.3,
#   'Lng': 86.0333,
#   'Max Temp': 258.06,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 0.46,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:49:22'},
#  {'City': 'Athabasca',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': 255.15,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:45:11'},
#  {'City': 'Nkhotakota',
#   'Lat': -12.9274,
#   'Lng': 34.2961,
#   'Max Temp': 295.71,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 1.71,
#   'Country': 'MW',
#   'Date': '2021-01-27 02:49:22'},
#  {'City': 'Yakeshi',
#   'Lat': 49.2833,
#   'Lng': 120.7333,
#   'Max Temp': 249.39,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 4.08,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:49:22'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 289.82,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:45:02'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 289.26,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.36,
#   'Country': 'MX',
#   'Date': '2021-01-27 02:49:23'},
#  {'City': 'Voi',
#   'Lat': -3.3945,
#   'Lng': 38.563,
#   'Max Temp': 293.82,
#   'Humidity': 88,
#   'Cloudiness': 35,
#   'Wind Speed': 0.71,
#   'Country': 'KE',
#   'Date': '2021-01-27 02:49:23'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 244.94,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 0.58,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:45:12'},
#  {'City': 'Tommot',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': 236.77,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.27,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:24'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 302.8,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Country': 'PG',
#   'Date': '2021-01-27 02:45:01'},
#  {'City': 'Moerai',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp': 300.4,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 6.04,
#   'Country': 'PF',
#   'Date': '2021-01-27 02:46:13'},
#  {'City': 'Bakloh',
#   'Lat': 32.4667,
#   'Lng': 75.9167,
#   'Max Temp': 279.9,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:49:24'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 246.15,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:20'},
#  {'City': 'Kalinovskaya',
#   'Lat': 43.5758,
#   'Lng': 45.5192,
#   'Max Temp': 269.15,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 1,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:25'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 301.51,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 8.15,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:49:25'},
#  {'City': 'Kangaatsiaq',
#   'Lat': 68.3065,
#   'Lng': -53.4641,
#   'Max Temp': 261.91,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:25'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 291.19,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 3.88,
#   'Country': 'MR',
#   'Date': '2021-01-27 02:45:43'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 272.15,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.77,
#   'Country': 'IS',
#   'Date': '2021-01-27 02:49:16'},
#  {'City': 'Lipari',
#   'Lat': 38.4674,
#   'Lng': 14.954,
#   'Max Temp': 283.71,
#   'Humidity': 55,
#   'Cloudiness': 39,
#   'Wind Speed': 1.34,
#   'Country': 'IT',
#   'Date': '2021-01-27 02:49:26'},
#  {'City': 'Yining',
#   'Lat': 29.0361,
#   'Lng': 114.5636,
#   'Max Temp': 280.74,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:49:26'},
#  {'City': 'Pasaje',
#   'Lat': -3.3333,
#   'Lng': -79.8167,
#   'Max Temp': 298.41,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 0.3,
#   'Country': 'EC',
#   'Date': '2021-01-27 02:49:26'},
#  {'City': 'Santa Isabel',
#   'Lat': -23.3156,
#   'Lng': -46.2214,
#   'Max Temp': 295.37,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:27'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 285.15,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'CL',
#   'Date': '2021-01-27 02:49:27'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 297.01,
#   'Humidity': 87,
#   'Cloudiness': 12,
#   'Wind Speed': 2.07,
#   'Country': 'MG',
#   'Date': '2021-01-27 02:49:27'},
#  {'City': 'Kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 276.15,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'JP',
#   'Date': '2021-01-27 02:49:27'},
#  {'City': 'Shalya',
#   'Lat': 57.2471,
#   'Lng': 58.7298,
#   'Max Temp': 264.13,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.73,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:28'},
#  {'City': 'Stepnyak',
#   'Lat': 52.8339,
#   'Lng': 70.7803,
#   'Max Temp': 267.2,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 6.44,
#   'Country': 'KZ',
#   'Date': '2021-01-27 02:49:28'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 298.52,
#   'Humidity': 88,
#   'Cloudiness': 84,
#   'Wind Speed': 2.45,
#   'Country': 'MZ',
#   'Date': '2021-01-27 02:45:45'},
#  {'City': 'Novikovo',
#   'Lat': 51.1537,
#   'Lng': 37.8879,
#   'Max Temp': 275.38,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.43,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:29'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 235.97,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:29'},
#  {'City': 'Belaya Gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': 238.99,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.24,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:29'},
#  {'City': 'Northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 282.04,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'GB',
#   'Date': '2021-01-27 02:49:29'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 295.58,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.12,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:49:30'},
#  {'City': 'Alto Araguaia',
#   'Lat': -17.3147,
#   'Lng': -53.2153,
#   'Max Temp': 294.22,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.6,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:30'},
#  {'City': 'Upata',
#   'Lat': 8.0086,
#   'Lng': -62.3989,
#   'Max Temp': 298.15,
#   'Humidity': 86,
#   'Cloudiness': 25,
#   'Wind Speed': 1.79,
#   'Country': 'VE',
#   'Date': '2021-01-27 02:49:30'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 302.99,
#   'Humidity': 58,
#   'Cloudiness': 58,
#   'Wind Speed': 2.38,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:49:30'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 250.37,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 0.96,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:31'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 294.15,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'CV',
#   'Date': '2021-01-27 02:45:53'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 291.15,
#   'Humidity': 82,
#   'Cloudiness': 15,
#   'Wind Speed': 2.06,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:49:31'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 272.15,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'NO',
#   'Date': '2021-01-27 02:46:18'},
#  {'City': 'Mitu',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 295.4,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 0.83,
#   'Country': 'CO',
#   'Date': '2021-01-27 02:49:32'},
#  {'City': 'Gornozavodsk',
#   'Lat': 58.3758,
#   'Lng': 58.3211,
#   'Max Temp': 262.8,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 3.43,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:32'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 262.89,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 3.07,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:32'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 290.15,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'JP',
#   'Date': '2021-01-27 02:49:14'},
#  {'City': 'El Tigre',
#   'Lat': 8.8875,
#   'Lng': -64.2454,
#   'Max Temp': 297.19,
#   'Humidity': 72,
#   'Cloudiness': 35,
#   'Wind Speed': 6.57,
#   'Country': 'VE',
#   'Date': '2021-01-27 02:49:33'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 244.05,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 2.21,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:33'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 286.7,
#   'Humidity': 61,
#   'Cloudiness': 52,
#   'Wind Speed': 4.45,
#   'Country': 'MX',
#   'Date': '2021-01-27 02:46:12'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 287.15,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'JP',
#   'Date': '2021-01-27 02:44:58'},
#  {'City': 'Alihe',
#   'Lat': 50.5667,
#   'Lng': 123.7167,
#   'Max Temp': 251.99,
#   'Humidity': 79,
#   'Cloudiness': 71,
#   'Wind Speed': 3.56,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:49:33'},
#  {'City': 'Santo Tomas',
#   'Lat': 14.1079,
#   'Lng': 121.1414,
#   'Max Temp': 301.15,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 1.54,
#   'Country': 'PH',
#   'Date': '2021-01-27 02:49:34'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 264.15,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:29'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 298.15,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'NZ',
#   'Date': '2021-01-27 02:49:08'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 291.15,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 8.75,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:34'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 300.38,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'GA',
#   'Date': '2021-01-27 02:49:35'},
#  {'City': 'Bay Roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 274.26,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:35'},
#  {'City': 'Fairlie',
#   'Lat': 55.756,
#   'Lng': -4.8556,
#   'Max Temp': 281.15,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 0.51,
#   'Country': 'GB',
#   'Date': '2021-01-27 02:49:35'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 284.82,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'JP',
#   'Date': '2021-01-27 02:49:35'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 298.15,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 0.51,
#   'Country': 'GF',
#   'Date': '2021-01-27 02:49:36'},
#  {'City': 'Monrovia',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 298.86,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind Speed': 1.99,
#   'Country': 'LR',
#   'Date': '2021-01-27 02:45:35'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 297.55,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.45,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:45:08'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 299.93,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 6.32,
#   'Country': 'SB',
#   'Date': '2021-01-27 02:49:36'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 238.6,
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 3.28,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:37'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 239.16,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:37'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 293.71,
#   'Humidity': 87,
#   'Cloudiness': 87,
#   'Wind Speed': 3.58,
#   'Country': 'PE',
#   'Date': '2021-01-27 02:49:37'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 284.06,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 0.95,
#   'Country': 'YE',
#   'Date': '2021-01-27 02:49:24'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 245.19,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:37'},
#  {'City': 'Albertville',
#   'Lat': 34.2676,
#   'Lng': -86.2089,
#   'Max Temp': 287.15,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 1.56,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:38'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 304.15,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'CK',
#   'Date': '2021-01-27 02:48:19'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 290.81,
#   'Humidity': 58,
#   'Cloudiness': 13,
#   'Wind Speed': 9.05,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:38'},
#  {'City': 'Kindu',
#   'Lat': -2.95,
#   'Lng': 25.95,
#   'Max Temp': 294.42,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'CD',
#   'Date': '2021-01-27 02:49:38'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 300.69,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 5.92,
#   'Country': 'NC',
#   'Date': '2021-01-27 02:49:39'},
#  {'City': 'Januaria',
#   'Lat': -15.4833,
#   'Lng': -44.3667,
#   'Max Temp': 295.61,
#   'Humidity': 69,
#   'Cloudiness': 7,
#   'Wind Speed': 2.28,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:39'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 277.04,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.23,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:39'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 263.76,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 4.32,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:39'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 298.15,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'RE',
#   'Date': '2021-01-27 02:49:39'},
#  {'City': 'Elko',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 267.04,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 1.33,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:40'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 297.04,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.58,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:49:40'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 245.81,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:40'},
#  {'City': 'Raboso',
#   'Lat': 18.5667,
#   'Lng': -98.45,
#   'Max Temp': 295.08,
#   'Humidity': 41,
#   'Cloudiness': 43,
#   'Wind Speed': 1.62,
#   'Country': 'MX',
#   'Date': '2021-01-27 02:45:12'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 282.15,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 1.54,
#   'Country': 'CL',
#   'Date': '2021-01-27 02:43:49'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 302.37,
#   'Humidity': 73,
#   'Cloudiness': 96,
#   'Wind Speed': 4.54,
#   'Country': 'PG',
#   'Date': '2021-01-27 02:49:41'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 298.15,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:44:50'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 291.24,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 0.94,
#   'Country': 'VE',
#   'Date': '2021-01-27 02:49:41'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 273.15,
#   'Humidity': 86,
#   'Cloudiness': 46,
#   'Wind Speed': 3.6,
#   'Country': 'FO',
#   'Date': '2021-01-27 02:49:42'},
#  {'City': 'Urubicha',
#   'Lat': -15.3833,
#   'Lng': -62.95,
#   'Max Temp': 295.57,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.84,
#   'Country': 'BO',
#   'Date': '2021-01-27 02:49:42'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 246.15,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 5.66,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:49:42'},
#  {'City': 'Olga',
#   'Lat': 43.7444,
#   'Lng': 135.2892,
#   'Max Temp': 267.67,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 7.54,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:42'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 300.15,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:49:43'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 293.15,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 8.23,
#   'Country': 'JP',
#   'Date': '2021-01-27 02:49:43'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 289.83,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'ML',
#   'Date': '2021-01-27 02:49:43'},
#  {'City': 'Montepuez',
#   'Lat': -13.1256,
#   'Lng': 38.9997,
#   'Max Temp': 292.91,
#   'Humidity': 99,
#   'Cloudiness': 10,
#   'Wind Speed': 1.4,
#   'Country': 'MZ',
#   'Date': '2021-01-27 02:49:43'},
#  {'City': 'Saurimo',
#   'Lat': -9.6608,
#   'Lng': 20.3916,
#   'Max Temp': 291.51,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.9,
#   'Country': 'AO',
#   'Date': '2021-01-27 02:49:43'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 274.12,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 12.2,
#   'Country': 'IS',
#   'Date': '2021-01-27 02:49:44'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 293.88,
#   'Humidity': 62,
#   'Cloudiness': 64,
#   'Wind Speed': 5.31,
#   'Country': 'NA',
#   'Date': '2021-01-27 02:49:44'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 292.71,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 1.32,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:49:44'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 244.34,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.41,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:44'},
#  {'City': 'Marrakesh',
#   'Lat': 31.6315,
#   'Lng': -8.0083,
#   'Max Temp': 286.15,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'MA',
#   'Date': '2021-01-27 02:49:45'},
#  {'City': 'Topolobampo',
#   'Lat': 25.6,
#   'Lng': -109.05,
#   'Max Temp': 287.04,
#   'Humidity': 71,
#   'Cloudiness': 26,
#   'Wind Speed': 1.79,
#   'Country': 'MX',
#   'Date': '2021-01-27 02:49:45'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 298.15,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'RE',
#   'Date': '2021-01-27 02:49:45'},
#  {'City': 'Ulaangom',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 247.43,
#   'Humidity': 80,
#   'Cloudiness': 83,
#   'Wind Speed': 0.3,
#   'Country': 'MN',
#   'Date': '2021-01-27 02:49:45'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 292.58,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 2.69,
#   'Country': 'CL',
#   'Date': '2021-01-27 02:49:46'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 302.75,
#   'Humidity': 59,
#   'Cloudiness': 78,
#   'Wind Speed': 0.86,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:47:01'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 299.25,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.79,
#   'Country': 'AO',
#   'Date': '2021-01-27 02:49:46'},
#  {'City': 'Bozoum',
#   'Lat': 6.3193,
#   'Lng': 16.3799,
#   'Max Temp': 294.75,
#   'Humidity': 33,
#   'Cloudiness': 95,
#   'Wind Speed': 1.21,
#   'Country': 'CF',
#   'Date': '2021-01-27 02:49:46'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 279.68,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'NP',
#   'Date': '2021-01-27 02:46:05'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 255.99,
#   'Humidity': 88,
#   'Cloudiness': 84,
#   'Wind Speed': 5.21,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:49:47'},
#  {'City': 'New Waterford',
#   'Lat': 40.8451,
#   'Lng': -80.6145,
#   'Max Temp': 274.26,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:47'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 300.65,
#   'Humidity': 74,
#   'Cloudiness': 37,
#   'Wind Speed': 6.98,
#   'Country': 'PF',
#   'Date': '2021-01-27 02:49:47'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 295.76,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 1.58,
#   'Country': 'CV',
#   'Date': '2021-01-27 02:49:47'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 294.26,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 4.02,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:43:48'},
#  {'City': 'Bakchar',
#   'Lat': 57.0186,
#   'Lng': 82.0711,
#   'Max Temp': 260.57,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.68,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:48'},
#  {'City': 'Bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 303.15,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:48'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 285.36,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 2.21,
#   'Country': 'EG',
#   'Date': '2021-01-27 02:49:49'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 267.15,
#   'Humidity': 79,
#   'Cloudiness': 11,
#   'Wind Speed': 2.06,
#   'Country': 'UZ',
#   'Date': '2021-01-27 02:49:49'},
#  {'City': 'Neryungri',
#   'Lat': 56.6709,
#   'Lng': 124.6491,
#   'Max Temp': 237.28,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 4.8,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:50'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 238.93,
#   'Humidity': 85,
#   'Cloudiness': 28,
#   'Wind Speed': 1.44,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:50'},
#  {'City': 'Bayburt',
#   'Lat': 40.2589,
#   'Lng': 40.2278,
#   'Max Temp': 265.74,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.38,
#   'Country': 'TR',
#   'Date': '2021-01-27 02:49:50'},
#  {'City': 'Mattoon',
#   'Lat': 39.4831,
#   'Lng': -88.3728,
#   'Max Temp': 272.15,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:50'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 275.37,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:25'},
#  {'City': 'Pampierstad',
#   'Lat': -27.7832,
#   'Lng': 24.6877,
#   'Max Temp': 293.78,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.57,
#   'Country': 'ZA',
#   'Date': '2021-01-27 02:49:51'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 288.8,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 2.74,
#   'Country': 'NE',
#   'Date': '2021-01-27 02:49:51'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 297.11,
#   'Humidity': 87,
#   'Cloudiness': 42,
#   'Wind Speed': 6.92,
#   'Country': 'SO',
#   'Date': '2021-01-27 02:49:51'},
#  {'City': 'Roxana',
#   'Lat': 10.2753,
#   'Lng': -83.7513,
#   'Max Temp': 291.48,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 3.13,
#   'Country': 'CR',
#   'Date': '2021-01-27 02:49:51'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 244.15,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 0.8,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:49:52'},
#  {'City': 'Singarayakonda',
#   'Lat': 15.25,
#   'Lng': 80.0333,
#   'Max Temp': 295.99,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 1.51,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:49:52'},
# ...
#   'Max Temp': 297.91,
#   'Humidity': 77,
#   'Cloudiness': 64,
#   'Wind Speed': 8.3,
#   'Country': 'SO',
#   'Date': '2021-01-27 02:50:56'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 250.37,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 0.95,
#   'Country': 'US',
#   'Date': '2021-01-27 02:48:43'},
#  {'City': 'Horana',
#   'Lat': 6.7166,
#   'Lng': 80.0619,
#   'Max Temp': 295.15,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 2.06,
#   'Country': 'LK',
#   'Date': '2021-01-27 02:50:56'},
#  {'City': 'Kollegal',
#   'Lat': 12.15,
#   'Lng': 77.1167,
#   'Max Temp': 292.15,
#   'Humidity': 82,
#   'Cloudiness': 38,
#   'Wind Speed': 0.58,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:50:57'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 299.58,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:50:57'},
#  {'City': 'Methoni',
#   'Lat': 36.8197,
#   'Lng': 21.7049,
#   'Max Temp': 281.48,
#   'Humidity': 76,
#   'Cloudiness': 3,
#   'Wind Speed': 7.2,
#   'Country': 'GR',
#   'Date': '2021-01-27 02:50:57'},
#  {'City': 'Bar-Le-Duc',
#   'Lat': 48.75,
#   'Lng': 5.1667,
#   'Max Temp': 276.15,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'FR',
#   'Date': '2021-01-27 02:50:57'},
#  {'City': 'Carauari',
#   'Lat': -4.8828,
#   'Lng': -66.8958,
#   'Max Temp': 296.67,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:50:58'},
#  {'City': 'Qiongshan',
#   'Lat': 20.0058,
#   'Lng': 110.3542,
#   'Max Temp': 292.15,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:50:58'},
#  {'City': 'Porto Novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 301.15,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'BJ',
#   'Date': '2021-01-27 02:50:58'},
#  {'City': 'North Bend',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 278.15,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.42,
#   'Country': 'US',
#   'Date': '2021-01-27 02:50:40'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 293.15,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind Speed': 8.75,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:50:59'},
#  {'City': 'Sayat',
#   'Lat': 38.7839,
#   'Lng': 63.8803,
#   'Max Temp': 269.15,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'TM',
#   'Date': '2021-01-27 02:50:59'},
#  {'City': 'Mitsamiouli',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 300.21,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 2.25,
#   'Country': 'KM',
#   'Date': '2021-01-27 02:50:59'},
#  {'City': 'Trapani',
#   'Lat': 37.8333,
#   'Lng': 12.6667,
#   'Max Temp': 284.82,
#   'Humidity': 46,
#   'Cloudiness': 77,
#   'Wind Speed': 3.58,
#   'Country': 'IT',
#   'Date': '2021-01-27 02:50:59'},
#  {'City': 'Mae Sai',
#   'Lat': 20.4335,
#   'Lng': 99.8762,
#   'Max Temp': 292.15,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'TH',
#   'Date': '2021-01-27 02:50:59'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 261,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Country': 'GL',
#   'Date': '2021-01-27 02:51:00'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 295.85,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 2.65,
#   'Country': 'MG',
#   'Date': '2021-01-27 02:51:00'},
#  {'City': 'Halifax',
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp': 273.15,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:48:03'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 273.15,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:00'},
#  {'City': 'Lao Cai',
#   'Lat': 22.4833,
#   'Lng': 103.95,
#   'Max Temp': 295.35,
#   'Humidity': 67,
#   'Cloudiness': 77,
#   'Wind Speed': 1.19,
#   'Country': 'VN',
#   'Date': '2021-01-27 02:48:12'},
#  {'City': 'Odweyne',
#   'Lat': 9.4092,
#   'Lng': 45.064,
#   'Max Temp': 288.55,
#   'Humidity': 54,
#   'Cloudiness': 96,
#   'Wind Speed': 1.04,
#   'Country': 'SO',
#   'Date': '2021-01-27 02:51:01'},
#  {'City': 'Channel-Port Aux Basques',
#   'Lat': 47.5702,
#   'Lng': -59.1367,
#   'Max Temp': 272.33,
#   'Humidity': 94,
#   'Cloudiness': 14,
#   'Wind Speed': 5.37,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:51:01'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 252.25,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:01'},
#  {'City': 'Cordoba',
#   'Lat': -31.4135,
#   'Lng': -64.1811,
#   'Max Temp': 296.15,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'AR',
#   'Date': '2021-01-27 02:49:14'},
#  {'City': 'Stanislav',
#   'Lat': 46.5691,
#   'Lng': 32.1478,
#   'Max Temp': 275.15,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 7,
#   'Country': 'UA',
#   'Date': '2021-01-27 02:51:02'},
#  {'City': 'Hongjiang',
#   'Lat': 27.11,
#   'Lng': 109.9956,
#   'Max Temp': 279.83,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:51:02'},
#  {'City': 'Tayu',
#   'Lat': -6.5397,
#   'Lng': 111.0518,
#   'Max Temp': 301.61,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 2.84,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:51:02'},
#  {'City': 'Champasak',
#   'Lat': 14.75,
#   'Lng': 106,
#   'Max Temp': 298.15,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'LA',
#   'Date': '2021-01-27 02:51:03'},
#  {'City': 'Sergeyevka',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Max Temp': 267.04,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'KZ',
#   'Date': '2021-01-27 02:51:03'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 276.15,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:51:03'},
#  {'City': 'Heishan',
#   'Lat': 41.6892,
#   'Lng': 122.1128,
#   'Max Temp': 266.91,
#   'Humidity': 67,
#   'Cloudiness': 8,
#   'Wind Speed': 2.08,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:51:04'},
#  {'City': 'Bulgan',
#   'Lat': 48.8125,
#   'Lng': 103.5347,
#   'Max Temp': 250.6,
#   'Humidity': 82,
#   'Cloudiness': 5,
#   'Wind Speed': 2.05,
#   'Country': 'MN',
#   'Date': '2021-01-27 02:51:04'},
#  {'City': 'Boralday',
#   'Lat': 43.3578,
#   'Lng': 76.8594,
#   'Max Temp': 264.25,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 0.16,
#   'Country': 'KZ',
#   'Date': '2021-01-27 02:51:04'},
#  {'City': 'San Ignacio',
#   'Lat': 17.1561,
#   'Lng': -89.0714,
#   'Max Temp': 296.48,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 1.92,
#   'Country': 'BZ',
#   'Date': '2021-01-27 02:51:05'},
#  {'City': 'Jinxi',
#   'Lat': 30.4323,
#   'Lng': 116.2922,
#   'Max Temp': 284.18,
#   'Humidity': 70,
#   'Cloudiness': 59,
#   'Wind Speed': 2.69,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:51:05'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 299.15,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 5.66,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:49:36'},
#  {'City': 'Akureyri',
#   'Lat': 65.6835,
#   'Lng': -18.0878,
#   'Max Temp': 262.15,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.38,
#   'Country': 'IS',
#   'Date': '2021-01-27 02:51:05'},
#  {'City': 'Cumberland',
#   'Lat': 35.0502,
#   'Lng': -78.8664,
#   'Max Temp': 285.93,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': '2021-01-27 02:51:06'},
#  {'City': 'Mansa',
#   'Lat': 29.9833,
#   'Lng': 75.3833,
#   'Max Temp': 282.15,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 1.72,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:49:20'},
#  {'City': 'Amberley',
#   'Lat': 39.2048,
#   'Lng': -84.428,
#   'Max Temp': 275.93,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': '2021-01-27 02:51:06'},
#  {'City': 'Zlobin',
#   'Lat': 45.2924,
#   'Lng': 14.6541,
#   'Max Temp': 274.15,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'HR',
#   'Date': '2021-01-27 02:51:06'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 289.82,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 3.93,
#   'Country': 'NE',
#   'Date': '2021-01-27 02:51:07'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 296.4,
#   'Humidity': 94,
#   'Cloudiness': 71,
#   'Wind Speed': 1.15,
#   'Country': 'MG',
#   'Date': '2021-01-27 02:50:20'},
#  {'City': 'Pithora',
#   'Lat': 21.2667,
#   'Lng': 82.5167,
#   'Max Temp': 292.35,
#   'Humidity': 50,
#   'Cloudiness': 64,
#   'Wind Speed': 2.6,
#   'Country': 'IN',
#   'Date': '2021-01-27 02:51:07'},
#  {'City': 'Koumac',
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 302.72,
#   'Humidity': 65,
#   'Cloudiness': 97,
#   'Wind Speed': 2.76,
#   'Country': 'NC',
#   'Date': '2021-01-27 02:51:07'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 297.18,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.93,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:51:08'},
#  {'City': 'Mattru',
#   'Lat': 7.6244,
#   'Lng': -11.8332,
#   'Max Temp': 296.08,
#   'Humidity': 93,
#   'Cloudiness': 28,
#   'Wind Speed': 0.82,
#   'Country': 'SL',
#   'Date': '2021-01-27 02:51:08'},
#  {'City': 'Port Hawkesbury',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 272.04,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.08,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:51:08'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 298.48,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 2.09,
#   'Country': 'MX',
#   'Date': '2021-01-27 02:51:08'},
#  {'City': 'Smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 266.15,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 0.59,
#   'Country': 'CA',
#   'Date': '2021-01-27 02:51:09'},
#  {'City': 'Santa Maria Del Oro',
#   'Lat': 25.9333,
#   'Lng': -105.3667,
#   'Max Temp': 282.73,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'MX',
#   'Date': '2021-01-27 02:51:09'},
#  {'City': 'Akhisar',
#   'Lat': 38.9185,
#   'Lng': 27.8401,
#   'Max Temp': 283.82,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.51,
#   'Country': 'TR',
#   'Date': '2021-01-27 02:51:09'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 301.54,
#   'Humidity': 73,
#   'Cloudiness': 98,
#   'Wind Speed': 3.02,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:51:09'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 232.46,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 0.87,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:09'},
#  {'City': 'Irtyshskiy',
#   'Lat': 58.3333,
#   'Lng': 68.1333,
#   'Max Temp': 268.29,
#   'Humidity': 98,
#   'Cloudiness': 96,
#   'Wind Speed': 3.43,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:10'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 273.71,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': '2021-01-27 02:50:37'},
#  {'City': 'Kongolo',
#   'Lat': -5.3833,
#   'Lng': 27,
#   'Max Temp': 293.32,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 0.72,
#   'Country': 'CD',
#   'Date': '2021-01-27 02:51:10'},
#  {'City': 'Capao Da Canoa',
#   'Lat': -29.7456,
#   'Lng': -50.0097,
#   'Max Temp': 297.79,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.31,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:51:11'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 299.18,
#   'Humidity': 83,
#   'Cloudiness': 48,
#   'Wind Speed': 5.02,
#   'Country': 'BR',
#   'Date': '2021-01-27 02:51:11'},
#  {'City': 'Caramay',
#   'Lat': 10.1815,
#   'Lng': 119.236,
#   'Max Temp': 301.64,
#   'Humidity': 67,
#   'Cloudiness': 31,
#   'Wind Speed': 3.79,
#   'Country': 'PH',
#   'Date': '2021-01-27 02:51:11'},
#  {'City': 'Creston',
#   'Lat': 41.0586,
#   'Lng': -94.3614,
#   'Max Temp': 264.15,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': '2021-01-27 02:51:12'},
#  {'City': 'Bridgetown',
#   'Lat': 13.1,
#   'Lng': -59.6167,
#   'Max Temp': 298.15,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 7.2,
#   'Country': 'BB',
#   'Date': '2021-01-27 02:51:12'},
#  {'City': 'Peniche',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 288.15,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 4.02,
#   'Country': 'PT',
#   'Date': '2021-01-27 02:51:12'},
#  {'City': 'Cabo Rojo',
#   'Lat': 18.0866,
#   'Lng': -67.1457,
#   'Max Temp': 297.04,
#   'Humidity': 94,
#   'Cloudiness': 2,
#   'Wind Speed': 3.38,
#   'Country': 'PR',
#   'Date': '2021-01-27 02:51:12'},
#  {'City': 'Seymchan',
#   'Lat': 62.8833,
#   'Lng': 152.4333,
#   'Max Temp': 241.51,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.53,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:13'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 285.37,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'PT',
#   'Date': '2021-01-27 02:51:13'},
#  {'City': 'Palu',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 304.25,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'ID',
#   'Date': '2021-01-27 02:46:31'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 276.15,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': '2021-01-27 02:51:14'},
#  {'City': 'Gigmoto',
#   'Lat': 13.7796,
#   'Lng': 124.39,
#   'Max Temp': 300.32,
#   'Humidity': 81,
#   'Cloudiness': 77,
#   'Wind Speed': 6.16,
#   'Country': 'PH',
#   'Date': '2021-01-27 02:49:10'},
#  {'City': 'Carballo',
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 286.48,
#   'Humidity': 94,
#   'Cloudiness': 92,
#   'Wind Speed': 0.45,
#   'Country': 'ES',
#   'Date': '2021-01-27 02:51:14'},
#  {'City': 'Ode',
#   'Lat': 7.7899,
#   'Lng': 5.7117,
#   'Max Temp': 293.68,
#   'Humidity': 32,
#   'Cloudiness': 8,
#   'Wind Speed': 1.41,
#   'Country': 'NG',
#   'Date': '2021-01-27 02:47:14'},
#  {'City': 'Jiayuguan',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 266.91,
#   'Humidity': 76,
#   'Cloudiness': 50,
#   'Wind Speed': 2.77,
#   'Country': 'CN',
#   'Date': '2021-01-27 02:51:15'},
#  {'City': 'Emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 307.59,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'AU',
#   'Date': '2021-01-27 02:51:15'},
#  {'City': 'Severnyy',
#   'Lat': 50.677,
#   'Lng': 36.5532,
#   'Max Temp': 273.15,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:15'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 283.15,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 0.22,
#   'Country': 'SA',
#   'Date': '2021-01-27 02:50:26'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 253.26,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 7.95,
#   'Country': 'MN',
#   'Date': '2021-01-27 02:51:05'},
#  {'City': 'Keetmanshoop',
#   'Lat': -26.5833,
#   'Lng': 18.1333,
#   'Max Temp': 293.72,
#   'Humidity': 37,
#   'Cloudiness': 43,
#   'Wind Speed': 5.97,
#   'Country': 'NA',
#   'Date': '2021-01-27 02:51:16'},
#  {'City': 'Andros Town',
#   'Lat': 24.7,
#   'Lng': -77.7667,
#   'Max Temp': 297.15,
#   'Humidity': 85,
#   'Cloudiness': 4,
#   'Wind Speed': 4.44,
#   'Country': 'BS',
#   'Date': '2021-01-27 02:51:16'},
#  {'City': 'Lander',
#   'Lat': 42.833,
#   'Lng': -108.7307,
#   'Max Temp': 264.15,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': '2021-01-27 02:49:53'},
#  {'City': 'Segezha',
#   'Lat': 63.7415,
#   'Lng': 34.3222,
#   'Max Temp': 273.04,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:51:16'},
#  {'City': 'Teguldet',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 250.25,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Country': 'RU',
#   'Date': '2021-01-27 02:50:19'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 283.15,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 3.51,
#   'Country': 'SA',
#   'Date': '2021-01-27 02:51:17'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hermanus -34.4187   19.2345    289.82        94          76        1.51
# 1    Carnarvon -24.8667  113.6333    298.15        50          40       12.86
# 2         Inta  66.0317   60.1659    243.21        83         100        5.66
# 3  Polonnaruwa   7.9333   81.0000    296.95        77         100        0.64
# 4      Aksarka  66.5606   67.7975    236.69        81           0        3.06
# 5       Vostok  46.4856  135.8833    258.98        93          99        5.57
# 6    Nanticoke  41.2054  -76.0049    273.15        93          99        0.45
# 7    Cape Town -33.9258   18.4232    292.59        82           0        5.66
# 8       Bethel  41.3712  -73.4140    270.93        93          90        2.02
# 9    Liverpool  53.4106   -2.9779    282.15        93          75        5.14
#
#   Country                 Date
# 0      ZA  2021-01-27 02:48:51
# 1      AU  2021-01-27 02:44:28
# 2      RU  2021-01-27 02:48:52
# 3      LK  2021-01-27 02:48:52
# 4      RU  2021-01-27 02:45:23
# 5      RU  2021-01-27 02:45:35
# 6      US  2021-01-27 02:48:53
# 7      ZA  2021-01-27 02:45:03
# 8      US  2021-01-27 02:48:53
# 9      GB  2021-01-27 02:48:31

# %%
new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Hermanus      ZA  2021-01-27 02:48:51 -34.4187   19.2345    289.82
# 1    Carnarvon      AU  2021-01-27 02:44:28 -24.8667  113.6333    298.15
# 2         Inta      RU  2021-01-27 02:48:52  66.0317   60.1659    243.21
# 3  Polonnaruwa      LK  2021-01-27 02:48:52   7.9333   81.0000    296.95
# 4      Aksarka      RU  2021-01-27 02:45:23  66.5606   67.7975    236.69
#
#    Humidity  Cloudiness  Wind Speed
# 0        94          76        1.51
# 1        50          40       12.86
# 2        83         100        5.66
# 3        77         100        0.64
# 4        81           0        3.06

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
