# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# airai pw
# castro cl
# san cristobal ec
# rikitea pf
# rikitea pf
# port elizabeth za
# fayaoue nc
# saint-joseph re
# mataura pf
# yellowknife ca
# jamestown sh
# atuona pf
# illoqqortoormiut gl
# bluff nz
# guerrero negro mx
# tatvan tr
# cape town za
# jiazi cn
# rabo de peixe pt
# narsaq gl
# longyearbyen sj
# nuuk gl
# busselton au
# itaituba br
# taolanaro mg
# barentsburg sj
# mehamn no
# punta arenas cl
# mataura pf
# rikitea pf
# taolanaro mg
# plainview us
# nizhneyansk ru
# kapaa us
# chokurdakh ru
# saldanha za
# bathsheba bb
# bay roberts ca
# tezu in
# synya ru
# faanui pf
# hualmay pe
# adela ph
# khatanga ru
# najran sa
# sitka us
# avarua ck
# hermanus za
# banda aceh id
# tuktoyaktuk ca
# saskylakh ru
# hofn is
# rawson ar
# kirovskaya ru
# liverpool ca
# cape town za
# rikitea pf
# tuktoyaktuk ca
# pisco pe
# ijaki ki
# yellowknife ca
# tual id
# port alfred za
# muzhi ru
# cape town za
# khandyga ru
# grajau br
# dikson ru
# akonolinga cm
# chokurdakh ru
# jamestown sh
# albany au
# east london za
# lorengau pg
# taolanaro mg
# nizwa om
# vaini to
# saldanha za
# attawapiskat ca
# busselton au
# ferrol es
# baudh in
# atasu kz
# upernavik gl
# sampit id
# nanortalik gl
# maua ke
# georgetown sh
# gainesville us
# tsiroanomandidy mg
# tiassale ci
# salamiyah sy
# port lincoln au
# rikitea pf
# mar del plata ar
# bredasdorp za
# georgetown sh
# hermanus za
# san rafael ar
# beringovskiy ru
# victoria sc
# yantal ru
# hilo us
# ballina au
# tenenkou ml
# saskylakh ru
# baculin ph
# rikitea pf
# vanavara ru
# puerto ayora ec
# dingle ie
# lompoc us
# sentyabrskiy ru
# cabo san lucas mx
# riyadh sa
# punta arenas cl
# kodiak us
# mao td
# mataura pf
# mataura pf
# rikitea pf
# arraial do cabo br
# kaitangata nz
# albany au
# mataura pf
# chuy uy
# berdigestyakh ru
# ponta do sol cv
# taolanaro mg
# rio grande br
# zalantun cn
# hasaki jp
# bluff nz
# castro cl
# apricena it
# apeldoorn nl
# manavalakurichi in
# nome us
# hobart au
# busselton au
# sao filipe cv
# barentsburg sj
# sabang id
# verkhnyachka ua
# hobart au
# upernavik gl
# barentsburg sj
# chuy uy
# keti bandar pk
# tasiilaq gl
# longyearbyen sj
# nabire id
# katobu id
# busselton au
# bluff nz
# kapaa us
# rikitea pf
# chokurdakh ru
# saint-philippe re
# port elizabeth za
# talnakh ru
# seoul kr
# tasiilaq gl
# port alfred za
# lebu cl
# hammerfest no
# ushuaia ar
# makat kz
# bastrop us
# grand river south east mu
# kodiak us
# ureki ge
# sibolga id
# boende cd
# tuktoyaktuk ca
# houma cn
# warrington us
# mataura pf
# uinskoye ru
# wesley dm
# oga jp
# tsihombe mg
# cape town za
# sao geraldo do araguaia br
# kingaroy au
# bambous virieux mu
# belushya guba ru
# veisiejai lt
# stromness gb
# atuona pf
# geraldton au
# cidreira br
# hobart au
# mataura pf
# iqaluit ca
# vaini to
# new norfolk au
# samusu ws
# rikitea pf
# bystryy istok ru
# torbay ca
# soyo ao
# veracruz mx
# ribeira grande pt
# katangli ru
# east london za
# prince rupert ca
# ati td
# samalaeulu ws
# batemans bay au
# tsihombe mg
# tasiilaq gl
# hobart au
# iqaluit ca
# hilo us
# katsuura jp
# parry sound ca
# marsh harbour bs
# luganville vu
# carutapera br
# sorland no
# severo-kurilsk ru
# port blair in
# qaanaaq gl
# hermanus za
# punta arenas cl
# tura ru
# hermanus za
# saleaula ws
# lascahobas ht
# chuy uy
# lompoc us
# sumbawa id
# ushuaia ar
# abha sa
# klichka ru
# arraial do cabo br
# mataura pf
# kaitangata nz
# faanui pf
# abadan ir
# rikitea pf
# bluff nz
# illoqqortoormiut gl
# chongqing cn
# saint george bm
# karkaralinsk kz
# hobart au
# san patricio mx
# skibbereen ie
# ponta do sol cv
# rikitea pf
# nampula mz
# khorixas na
# uige ao
# qaanaaq gl
# marcona pe
# novikovo ru
# saint-philippe re
# saskylakh ru
# norman wells ca
# san carlos de bariloche ar
# matay eg
# los llanos de aridane es
# avarua ck
# bluff nz
# hilo us
# ushuaia ar
# nikolskoye ru
# yellowknife ca
# rikitea pf
# mao td
# vaini to
# vao nc
# victoria sc
# rikitea pf
# fevralsk ru
# thompson ca
# bereda so
# albany au
# sorland no
# dikson ru
# avarua ck
# mataura pf
# dudinka ru
# lolua tv
# mataura pf
# lebu cl
# ribeira grande pt
# cooma au
# elizabeth city us
# narsaq gl
# punta arenas cl
# hambantota lk
# sri aman my
# filingue ne
# narsaq gl
# kalispell us
# labytnangi ru
# mount isa au
# karwar in
# kapaa us
# plattsburgh us
# skagastrond is
# bluff nz
# flinders au
# pevek ru
# barrow us
# amargosa br
# hithadhoo mv
# albany au
# hithadhoo mv
# chuy uy
# horsham au
# lubumbashi cd
# tiksi ru
# petropavlovsk-kamchatskiy ru
# jamestown sh
# pervoye maya ru
# ilulissat gl
# ossora ru
# coquimbo cl
# mayo ca
# yenagoa ng
# ushuaia ar
# ushuaia ar
# torbay ca
# presidencia roque saenz pena ar
# provideniya ru
# arraial do cabo br
# teneguiban ph
# tuktoyaktuk ca
# hobart au
# rafaela ar
# kavieng pg
# isabela us
# avarua ck
# manta ec
# marcona pe
# morgan city us
# salalah om
# kaeo nz
# rungata ki
# busselton au
# rungata ki
# east london za
# nikolskoye ru
# oranjestad aw
# thompson ca
# jamestown sh
# east london za
# punta arenas cl
# hermanus za
# mataura pf
# mys shmidta ru
# berlevag no
# bengkulu id
# zavallya ua
# chokurdakh ru
# humaita br
# atar mr
# khatanga ru
# marsh harbour bs
# hobart au
# coquimbo cl
# henties bay na
# sitka us
# rikitea pf
# mataura pf
# hithadhoo mv
# hermanus za
# mataura pf
# cape town za
# vaini to
# miguel hidalgo mx
# kapaa us
# airai pw
# barentsburg sj
# cape town za
# kaduqli sd
# kapaa us
# jamestown sh
# cayenne gf
# ambunti pg
# necochea ar
# jasper ca
# rikitea pf
# havre us
# karamay cn
# atuona pf
# mayumba ga
# taolanaro mg
# mount hagen pg
# taolanaro mg
# ulcinj me
# port hedland au
# taolanaro mg
# tasiilaq gl
# talmenka ru
# adrar dz
# ushuaia ar
# illoqqortoormiut gl
# san luis rio colorado mx
# ribeira grande pt
# ballina au
# ituni gy
# ushuaia ar
# nizwa om
# port elizabeth za
# altamira br
# belushya guba ru
# port lincoln au
# dingle ie
# lasa cn
# kalur kot pk
# alofi nu
# bredasdorp za
# clinton us
# qaanaaq gl
# neudorfl at
# adrar dz
# pisco pe
# nizhneyansk ru
# port alfred za
# westport nz
# dunedin nz
# ilulissat gl
# vostok ru
# jamestown sh
# jamestown sh
# grand gaube mu
# atuona pf
# zheshart ru
# klaksvik fo
# kapaa us
# vaini to
# brae gb
# puerto ayora ec
# mahebourg mu
# longyearbyen sj
# hurghada eg
# hobart au
# bathsheba bb
# busselton au
# arraial do cabo br
# lagoa pt
# albany au
# obuasi gh
# kapaa us
# busselton au
# mahebourg mu
# butaritari ki
# lavrentiya ru
# yokadouma cm
# kensington ca
# hobart au
# nizhneangarsk ru
# khatanga ru
# poum nc
# butaritari ki
# marabba sd
# vao nc
# stornoway gb
# palabuhanratu id
# puerto ayora ec
# avarua ck
# awbari ly
# fortuna us
# yellowknife ca
# chuy uy
# port lincoln au
# la grande us
# rikitea pf
# karaton kz
# sao felix do xingu br
# urozhayne ua
# taolanaro mg
# ushuaia ar
# jamestown sh
# mataura pf
# faanui pf
# taolanaro mg
# atuona pf
# sovetskiy ru
# hasaki jp
# hualmay pe
# farmington us
# mahon es
# tumannyy ru
# illoqqortoormiut gl
# urusha ru
# nunoa pe
# carnarvon au
# furstenwalde de
# saint-philippe re
# nikolskoye ru
# georgetown sh
# bethel us
# provideniya ru
# saint-philippe re
# shaoxing cn
# albany au
# hilo us
# samarai pg
# gander ca
# codrington ag
# north platte us
# busselton au
# atuona pf
# tomatlan mx
# hithadhoo mv
# provideniya ru
# sitka us
# georgetown sh
# cape town za
# una br
# vaini to
# mataura pf
# severo-kurilsk ru
# nassau bs
# taolanaro mg
# villa bruzual ve
# mataura pf
# chokurdakh ru
# houston ca
# avera pf
# castro cl
# tuktoyaktuk ca
# port alfred za
# tiksi ru
# busselton au
# kieta pg
# butaritari ki
# hobart au
# dawlatabad af
# cape town za
# chokurdakh ru
# qaanaaq gl
# busselton au
# yellowknife ca
# albany au
# surt ly
# upernavik gl
# punta arenas cl
# altay cn
# hermanus za
# swinford ie
# mar del plata ar
# jamestown sh
# ancud cl
# henties bay na
# bambanglipuro id
# souillac mu
# severo-yeniseyskiy ru
# ahipara nz
# belyy yar ru
# amos ca
# port macquarie au
# ushuaia ar
# mys shmidta ru
# punta arenas cl
# hithadhoo mv
# fairbanks us
# resistencia ar
# port alfred za
# rikitea pf
# bluff nz
# oxbow ca
# rikitea pf
# portland au
# honiara sb
# oancea ro
# yar-sale ru
# tuktoyaktuk ca
# kouango cf
# kavieng pg
# partizanskoye ru
# bethel us
# tonstad no
# mahebourg mu
# hobart au
# busselton au
# taolanaro mg
# qaanaaq gl
# alice springs au
# winona us
# port alfred za
# bluff nz
# komsomolskiy ru
# qaanaaq gl
# marzuq ly
# batemans bay au
# jamestown sh
# klyuchi ru
# port elizabeth za
# rikitea pf
# parakai nz
# albany au
# mataura pf
# cayenne gf
# jamestown sh
# maniitsoq gl
# pevek ru
# muroto jp
# arraial do cabo br
# dicabisagan ph
# nuuk gl
# illoqqortoormiut gl
# barisal bd
# port elizabeth za
# albany au
# chudniv ua
# east london za
# albany au
# quatre cocos mu
# punta arenas cl
# peterhead gb
# chokurdakh ru
# jibuti dj
# boende cd
# san quintin mx
# tual id
# vila franca do campo pt
# kenora ca
# rikitea pf
# esperance au
# bahir dar et
# bluff nz
# victoria sc
# mataura pf
# san quintin mx
# rikitea pf
# cape town za
# bluff nz
# illoqqortoormiut gl
# hilo us
# goderich sl
# butaritari ki
# adrar dz
# punta arenas cl
# vila velha br
# izhma ru
# vaini to
# predivinsk ru
# new norfolk au
# ushuaia ar
# roma au
# kendari id
# butaritari ki
# ancud cl
# busselton au
# la ronge ca
# poum nc
# busselton au
# norman wells ca
# amga ru
# dicabisagan ph
# tuktoyaktuk ca
# fenoarivo mg
# ararat au
# visby se
# attawapiskat ca
# mataura pf
# hermanus za
# bonavista ca
# verkhnevilyuysk ru
# poum nc
# laguna br
# mahebourg mu
# belushya guba ru
# albany au
# artyom az
# leningradskiy ru
# chabahar ir
# dikson ru
# ushuaia ar
# yellowknife ca
# jamestown sh
# punta arenas cl
# busselton au
# bluff nz
# georgetown sh
# pemangkat id
# kandry ru
# atuona pf
# batagay-alyta ru
# albany au
# qaqortoq gl
# rikitea pf
# punta arenas cl
# verkh-usugli ru
# ushuaia ar
# khatanga ru
# tiksi ru
# birao cf
# rikitea pf
# severo-kurilsk ru
# skjervoy no
# tarakan id
# busselton au
# cabo san lucas mx
# fort nelson ca
# bursa tr
# ushuaia ar
# jamestown sh
# atuona pf
# ushuaia ar
# torres br
# puerto ayora ec
# saint george bm
# saint-pierre pm
# esperance au
# kapaa us
# lorengau pg
# hobart au
# bluff nz
# porto novo cv
# najran sa
# rocha uy
# lorengau pg
# belyy yar ru
# albany au
# loreto mx
# codrington ag
# nouadhibou mr
# atuona pf
# vaini to
# kapaa us
# baykit ru
# kahului us
# yar-sale ru
# porangatu br
# rikitea pf
# lompoc us
# hofn is
# punta arenas cl
# lompoc us
# busselton au
# belushya guba ru
# mataura pf
# bethel us
# nha trang vn
# codrington ag
# te anau nz
# san patricio mx
# otane nz
# ushuaia ar
# niono ml
# druskininkai lt
# yumen cn
# georgetown sh
# saint-philippe re
# ustyuzhna ru
# ocala us
# kyshtovka ru
# busselton au
# bara sd
# ushuaia ar
# chiriguana co
# tuatapere nz
# bluff nz
# pevek ru
# adrar dz
# lorengau pg
# puerto ayacucho ve
# sentyabrskiy ru
# makasar id
# tsihombe mg
# butembo cd
# albany au
# aksha ru
# jamestown sh
# albany au
# mys shmidta ru
# sataua ws
# riyadh sa
# inuvik ca
# castro cl
# te anau nz
# villa carlos paz ar
# deputatskiy ru
# butaritari ki
# butaritari ki
# yanagawa jp
# ondorhaan mn
# mrirt ma
# vaini to
# butaritari ki
# vaini to
# barrow us
# longyearbyen sj
# tumannyy ru
# west wendover us
# esik kz
# natitingou bj
# katsuura jp
# port elizabeth za
# hermanus za
# tilichiki ru
# chokurdakh ru
# port elizabeth za
# carnarvon au
# chitungwiza zw
# half moon bay us
# broken hill au
# nantucket us
# mar del plata ar
# kenora ca
# port hardy ca
# mar del plata ar
# scottsburgh za
# rio gallegos ar
# codrington ag
# isangel vu
# busselton au
# albany au
# hirara jp
# gobabis na
# taksimo ru
# tsihombe mg
# kaitangata nz
# castro cl
# broome au
# rikitea pf
# mattru sl
# seoul kr
# avarua ck
# hovd mn
# butaritari ki
# bethel us
# zhezkazgan kz
# kapaa us
# arraial do cabo br
# bluff nz
# ambilobe mg
# ushuaia ar
# yirol sd
# busselton au
# grand centre ca
# san policarpo ph
# dingle ie
# saint george bm
# jamestown sh
# samarai pg
# codrington ag
# busselton au
# mataura pf
# kodiak us
# albany au
# tuktoyaktuk ca
# lebu cl
# esperance au
# mataura pf
# muisne ec
# ushuaia ar
# busselton au
# iqaluit ca
# georgetown sh
# taolanaro mg
# richards bay za
# belushya guba ru
# kawalu id
# auki sb
# ponta do sol pt
# cape town za
# vila franca do campo pt
# puerto ayora ec
# rikitea pf
# punta arenas cl
# taolanaro mg
# yellowknife ca
# carnarvon au
# ribeira grande pt
# punta arenas cl
# byron bay au
# touros br
# meulaboh id
# salym ru
# mindelo cv
# souillac mu
# khatanga ru
# punta arenas cl
# nikolskoye ru
# vardo no
# punta arenas cl
# cabedelo br
# yellowknife ca
# bredasdorp za
# nouadhibou mr
# bucksport us
# roald no
# sur om
# vardo no
# todos santos mx
# luanda ao
# punta arenas cl
# east london za
# attawapiskat ca
# ixtapa mx
# asau tv
# pareora nz
# graaff-reinet za
# carutapera br
# punta arenas cl
# sainte-suzanne re
# amderma ru
# saint-philippe re
# yellowknife ca
# ushuaia ar
# amga ru
# shimoda jp
# andenes no
# kaputa zm
# leningradskiy ru
# victoria sc
# port elizabeth za
# ribeira grande pt
# taolanaro mg
# esperance au
# hithadhoo mv
# taveta ke
# ijaki ki
# torbay ca
# marcona pe
# saint-philippe re
# albany au
# tuktoyaktuk ca
# pemberton ca
# albany au
# atuona pf
# gornyatskiy ru
# oistins bb
# busselton au
# provideniya ru
# cabo san lucas mx
# moosomin ca
# bluff nz
# nyimba zm
# ridgecrest us
# taolanaro mg
# meridian us
# vaini to
# bluff nz
# saint-philippe re
# kaka tm
# new norfolk au
# artvin tr
# labuhan id
# jamestown sh
# katobu id
# atuona pf
# hilo us
# atuona pf
# nehe cn
# anadyr ru
# ushuaia ar
# mareeba au
# augusto correa br
# hithadhoo mv
# new norfolk au
# zhigansk ru
# saskylakh ru
# khatanga ru
# faya td
# ushuaia ar
# yeppoon au
# ushuaia ar
# vaini to
# rikitea pf
# castro cl
# vaini to
# butaritari ki
# albany au
# ilulissat gl
# pisco pe
# zyryanka ru
# hithadhoo mv
# tolaga bay nz
# ushuaia ar
# bredasdorp za
# tiksi ru
# acapulco mx
# san quintin mx
# vangaindrano mg
# desdunes ht
# albany au
# ushuaia ar
# carauari br
# hobart au
# mabaruma gy
# tilichiki ru
# banyo cm
# koslan ru
# busselton au
# leh in
# yellowknife ca
# aasiaat gl
# ushuaia ar
# moose factory ca
# severo-kurilsk ru
# sindi in
# qaanaaq gl
# namibe ao
# camana pe
# moose factory ca
# bengkulu id
# alofi nu
# punta arenas cl
# orgun af
# frondenberg de
# shubarkuduk kz
# mataura pf
# port elizabeth za
# lixourion gr
# amarante do maranhao br
# margate za
# baft ir
# saldanha za
# shubarshi kz
# faanui pf
# mataura pf
# airai pw
# caravelas br
# mahebourg mu
# mount gambier au
# grindavik is
# albany au
# nelson bay au
# presidencia roque saenz pena ar
# ushuaia ar
# hobart au
# constitucion mx
# hithadhoo mv
# yellapur in
# lata sb
# vestmannaeyjar is
# lavrentiya ru
# susangerd ir
# cape town za
# galle lk
# murray bridge au
# nikolskoye ru
# barabai id
# avarua ck
# port alfred za
# deputatskiy ru
# illoqqortoormiut gl
# praia da vitoria pt
# illoqqortoormiut gl
# butaritari ki
# tabou ci
# mataura pf
# upernavik gl
# belushya guba ru
# chokurdakh ru
# rikitea pf
# punta arenas cl
# riachao br
# saint-philippe re
# sitka us
# lolua tv
# jumla np
# hermanus za
# sobolevo ru
# rikitea pf
# hilo us
# straumen no
# provideniya ru
# san patricio mx
# suntar ru
# illoqqortoormiut gl
# arraial do cabo br
# vaini to
# te anau nz
# albany au
# saldanha za
# ushuaia ar
# mantua cu
# hobart au
# upernavik gl
# severo-kurilsk ru
# kodiak us
# the valley ai
# jamestown sh
# taoudenni ml
# werda bw
# seymchan ru
# rikitea pf
# cape town za
# vila franca do campo pt
# kodiak us
# malanje ao
# new norfolk au
# geraldton au
# pangnirtung ca
# dingle ie
# cabo san lucas mx
# esperance au
# itarema br
# hobart au
# bonthe sl
# albany au
# san cristobal ec
# aksu cn
# illoqqortoormiut gl
# cherskiy ru
# outjo na
# yellowknife ca
# dingle ie
# ancud cl
# puerto ayora ec
# atuona pf
# agadez ne
# provideniya ru
# rikitea pf
# ushuaia ar
# praia da vitoria pt
# talnakh ru
# thompson ca
# tuktoyaktuk ca
# talara pe
# rikitea pf
# ostrovnoy ru
# illoqqortoormiut gl
# belushya guba ru
# caravelas br
# colac au
# pevek ru
# falealupo ws
# souillac mu
# sakakah sa
# oromocto ca
# wa gh
# bredasdorp za
# constantine dz
# taolanaro mg
# san ramon bo
# pangody ru
# marawi sd
# salalah om
# port blair in
# norman wells ca
# vaini to
# souillac mu
# arraial do cabo br
# souillac mu
# nikolskoye ru
# carnarvon au
# saint george bm
# chokurdakh ru
# samoded ru
# arlit ne
# punta arenas cl
# yerbogachen ru
# rikitea pf
# hithadhoo mv
# saskylakh ru
# atuona pf
# pevek ru
# yichun cn
# rikitea pf
# tuktoyaktuk ca
# tiksi ru
# puerto ayora ec
# muswellbrook au
# victoria sc
# ushuaia ar
# djambala cg
# petrozavodsk ru
# yakovlevo ru
# barrow us
# kapaa us
# bose cn
# bengkulu id
# thinadhoo mv
# upernavik gl
# san pedro ar
# butaritari ki
# tuktoyaktuk ca
# cape town za
# dikson ru
# puerto ayora ec
# waipawa nz
# broome au
# belem de sao francisco br
# suzhou cn
# hobart au
# mataura pf
# cape town za
# mataura pf
# bredasdorp za
# rio grande br
# port alfred za
# hasaki jp
# mataura pf
# taolanaro mg
# belushya guba ru
# marsabit ke
# ushuaia ar
# rikitea pf
# jamestown sh
# rikitea pf
# deputatskiy ru
# severo-kurilsk ru
# new norfolk au
# hobart au
# ushuaia ar
# port elizabeth za
# mys shmidta ru
# mataura pf
# dunedin nz
# ostrovnoy ru
# amderma ru
# sorvag fo
# avera pf
# port alfred za
# silifke tr
# chokurdakh ru
# longyearbyen sj
# vila velha br
# norman wells ca
# busselton au
# tukrah ly
# hithadhoo mv
# punta arenas cl
# butaritari ki
# busselton au
# chokurdakh ru
# svetlogorsk ru
# bluff nz
# jamestown sh
# arraial do cabo br
# myitkyina mm
# san cristobal ec
# buraydah sa
# westport nz
# tsihombe mg
# belushya guba ru
# samusu ws
# saskylakh ru
# ubala co
# kichera ru
# great bend us
# grand river south east mu
# puerto ayora ec
# gendringen nl
# biak id
# jandaia do sul br
# giyani za
# fairview ca
# airai pw
# lebu cl
# hami cn
# saskylakh ru
# san cristobal ec
# bambous virieux mu
# arraial do cabo br
# bluff nz
# saint-philippe re
# thompson ca
# tocopilla cl
# rikitea pf
# samarai pg
# morti pa
# hofn is
# rio gallegos ar
# punta arenas cl
# pevek ru
# dikson ru
# khatanga ru
# vaini to
# ponta do sol cv
# husavik is
# mama ru
# jamestown sh
# shenjiamen cn
# daman in
# kapaa us
# khandbari np
# puerto ayora ec
# natal br
# lompoc us
# tabou ci
# taolanaro mg
# orlik ru
# taolanaro mg
# sabang id
# adrar dz
# bredasdorp za
# butaritari ki
# antofagasta cl
# sambava mg
# san quintin mx
# ushuaia ar
# bredasdorp za
# taolanaro mg
# ushuaia ar
# leh in
# ushuaia ar
# hobyo so
# bluff nz
# bathsheba bb
# yar-sale ru
# inhambane mz
# amderma ru
# longlac ca
# san patricio mx
# aksu kz
# butaritari ki
# hilo us
# atuona pf
# qaanaaq gl
# totness sr
# mar del plata ar
# belushya guba ru
# viet tri vn
# granville fr
# hibbing us
# tytuvenai lt
# vardo no
# georgetown sh
# vaini to
# aasiaat gl
# taolanaro mg
# walcz pl
# namibe ao
# esperance au
# college us
# puerto ayora ec
# sao felix do xingu br
# mitu co
# albany au
# albany au
# puerto ayora ec
# kudahuvadhoo mv
# kitimat ca
# grand river south east mu
# mys shmidta ru
# acapulco mx
# bluff nz
# hasaki jp
# souillac mu
# komsomolskiy ru
# baruun-urt mn
# castro cl
# yellowknife ca
# ghanzi bw
# saint-philippe re
# havoysund no
# taolanaro mg
# yellowknife ca
# aklavik ca
# hovd mn
# zhangye cn
# sao filipe cv
# dickinson us
# bluff nz
# grand gaube mu
# coihaique cl
# qaanaaq gl
# hermanus za
# bredasdorp za
# alice springs au
# geraldton au
# vaini to
# saint-philippe re
# tessalit ml
# isangel vu
# ushuaia ar
# dengzhou cn
# rikitea pf
# hurghada eg
# busselton au
# pemangkat id
# celestun mx
# balagansk ru
# kaitangata nz
# vaitupu wf
# awjilah ly
# yulara au
# tuktoyaktuk ca
# kapaa us
# barrow us
# tuatapere nz
# vanderhoof ca
# banjar id
# mar del plata ar
# rikitea pf
# bengkulu id
# rikitea pf
# kahului us
# hermanus za
# ushuaia ar
# hermanus za
# hithadhoo mv
# talnakh ru
# rikitea pf
# victoria sc
# husavik is
# twentynine palms us
# mount gambier au
# samarai pg
# tuktoyaktuk ca
# ketchenery ru
# port-gentil ga
# taolanaro mg
# dikson ru
# pisco pe
# salalah om
# moindou nc
# krasnokamensk ru
# severo-kurilsk ru
# teguise es
# albany au
# balikpapan id
# tuktoyaktuk ca
# zhanaozen kz
# tofield ca
# nikolskoye ru
# tomatlan mx
# thouars fr
# taolanaro mg
# barentsburg sj
# punta arenas cl
# husavik is
# flinders au
# albany au
# ust-nera ru
# eidfjord no
# taolanaro mg
# albany au
# hobart au
# ribeira grande pt
# castro cl
# hermanus za
# chitrakonda in
# kapaa us
# neiafu to
# mount isa au
# busselton au
# rikitea pf
# oyek ru
# cape town za
# clyde river ca
# hermanus za
# merauke id
# jamestown sh
# rikitea pf
# rikitea pf
# victor harbor au
# castro cl
# mahebourg mu
# ayorou ne
# naze jp
# saskylakh ru
# kuche cn
# san-pedro ci
# bandarbeyla so
# ponta do sol cv
# jiddah sa
# yellowknife ca
# ushuaia ar
# nikolskoye ru
# jamestown sh
# punta arenas cl
# constitucion cl
# qaanaaq gl
# rikitea pf
# luderitz na
# bredasdorp za
# punta arenas cl
# komsomolskiy ru
# tazmalt dz
# el tigre ve
# salina cruz mx
# saint-philippe re
# tuktoyaktuk ca
# hilo us
# wald-michelbach de
# moldava nad bodvou sk
# avarua ck
# saint-augustin ca
# fortuna us
# nhulunbuy au
# bluff nz
# ushuaia ar
# jabiru au
# punta arenas cl
# hobart au
# nong phai th
# bluff nz
# synya ru
# punta arenas cl
# ostersund se
# kalanguy ru
# marsa matruh eg
# rikitea pf
# ferrol es
# chuy uy
# kargasok ru

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 648

# %%
# Import the requests library.
import requests

# Import the API key.
from config import api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9f5d46bf6a7d704c75adb499630dd088

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9f5d46bf6a7d704c75adb499630dd088&q=Boston

# %%
import requests
from config import api_key

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&"
city = "London"

# %%
query_url = url + "appid=" + api_key + "&q=" + city
print(query_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9f5d46bf6a7d704c75adb499630dd088&q=London

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# %%
weather_json.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
weather_json.get("main")
# Out:
# {'temp': 49.28,
#  'feels_like': 45.01,
#  'temp_min': 48,
#  'temp_max': 51.01,
#  'pressure': 1012,
#  'humidity': 87}

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [401]>

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + api_key + "&q=" +"Boston" 
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9f5d46bf6a7d704c75adb499630dd088&q=Boston

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":701,"main":"Mist","description":"mist","icon":"50d"}],"base":"stations","main":{"temp":32.34,"feels_like":23.38,"temp_min":30.2,"temp_max":34,"pressure":1016,"humidity":93},"visibility":9656,"wind":{"speed":9.22,"deg":340},"clouds":{"all":90},"dt":1611762407,"sys":{"type":1,"id":3486,"country":"US","sunrise":1611748944,"sunset":1611784288},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 701,
#    'main': 'Mist',
#    'description': 'mist',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 32.34,
#   'feels_like': 23.38,
#   'temp_min': 30.2,
#   'temp_max': 34,
#   'pressure': 1016,
#   'humidity': 93},
#  'visibility': 9656,
#  'wind': {'speed': 9.22, 'deg': 340},
#  'clouds': {'all': 90},
#  'dt': 1611762407,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611748944,
#   'sunset': 1611784288},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + api_key + "&q=" + "Bston"


city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + api_key + "&q=" +"Boston" 
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 701,
#    'main': 'Mist',
#    'description': 'mist',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 32.34,
#   'feels_like': 23.38,
#   'temp_min': 30.2,
#   'temp_max': 34,
#   'pressure': 1016,
#   'humidity': 93},
#  'visibility': 9656,
#  'wind': {'speed': 9.22, 'deg': 340},
#  'clouds': {'all': 90},
#  'dt': 1611762407,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611748944,
#   'sunset': 1611784288},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data["sys"]
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1611748944,
#  'sunset': 1611784288}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1611762407

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 34 93 90 9.22

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 1, 27, 15, 46, 47)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H: %M: %S')
# Out:
# '2021-01-27 15: 46: 47'

# %%
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9f5d46bf6a7d704c75adb499630dd088&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    #city_url = url + "&q=" + city.replace(" ","+")
    city_url = url + "appid=" + api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | male
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | dawlatabad
# Processing Record 6 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | kuybysheve
# Processing Record 13 of Set 1 | etchoropo
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | rio bananal
# Processing Record 16 of Set 1 | bestobe
# Processing Record 17 of Set 1 | buin
# Processing Record 18 of Set 1 | hirara
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | hokitika
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | kavieng
# Processing Record 23 of Set 1 | morro bay
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | honiara
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | shenjiamen
# Processing Record 30 of Set 1 | kaeo
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | rio gallegos
# Processing Record 34 of Set 1 | ilesha
# Processing Record 35 of Set 1 | wakkanai
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | bandarbeyla
# Processing Record 43 of Set 1 | charagua
# Processing Record 44 of Set 1 | sarahan
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 1 | kombissiri
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | soubre
# Processing Record 3 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | bathsheba
# Processing Record 7 of Set 2 | ternovskaya
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | cockburn town
# Processing Record 11 of Set 2 | shingu
# Processing Record 12 of Set 2 | yerbogachen
# Processing Record 13 of Set 2 | sorland
# Processing Record 14 of Set 2 | bourail
# Processing Record 15 of Set 2 | tautira
# Processing Record 16 of Set 2 | walvis bay
# Processing Record 17 of Set 2 | cap malheureux
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | voh
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | araouane
# Processing Record 23 of Set 2 | solnechnyy
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | touros
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | matara
# Processing Record 31 of Set 2 | tabou
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | havelock
# Processing Record 34 of Set 2 | manokwari
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | imbituba
# Processing Record 37 of Set 2 | kamenka
# Processing Record 38 of Set 2 | cabedelo
# Processing Record 39 of Set 2 | saint-augustin
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | dalvik
# Processing Record 42 of Set 2 | gewane
# Processing Record 43 of Set 2 | fairbanks
# Processing Record 44 of Set 2 | harsin
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | beringovskiy
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | belaya gora
# Processing Record 3 of Set 3 | tarko-sale
# Processing Record 4 of Set 3 | matamoros
# Processing Record 5 of Set 3 | san cristobal
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | portobelo
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | antalaha
# Processing Record 12 of Set 3 | shakawe
# Processing Record 13 of Set 3 | olinda
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | mineiros
# Processing Record 18 of Set 3 | ormara
# Processing Record 19 of Set 3 | kalmunai
# Processing Record 20 of Set 3 | pangnirtung
# Processing Record 21 of Set 3 | luau
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | batagay-alyta
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | changde
# Processing Record 28 of Set 3 | sibolga
# Processing Record 29 of Set 3 | leningradskiy
# Processing Record 30 of Set 3 | eureka
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 3 | los llanos de aridane
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | aguimes
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | grindavik
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | zabid
# Processing Record 44 of Set 3 | northam
# Processing Record 45 of Set 3 | tomatlan
# Processing Record 46 of Set 3 | ucluelet
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | srednekolymsk
# Processing Record 49 of Set 3 | goulburn
# Processing Record 50 of Set 3 | wairoa
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | kieta
# Processing Record 3 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | broome
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | biltine
# Processing Record 8 of Set 4 | umarizal
# Processing Record 9 of Set 4 | turukhansk
# Processing Record 10 of Set 4 | alto araguaia
# Processing Record 11 of Set 4 | kabinda
# Processing Record 12 of Set 4 | deputatskiy
# Processing Record 13 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | sangar
# Processing Record 16 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 4 | inuvik
# Processing Record 18 of Set 4 | aklavik
# Processing Record 19 of Set 4 | santa maria
# Processing Record 20 of Set 4 | itoman
# Processing Record 21 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 4 | bairiki
# Processing Record 23 of Set 4 | muros
# Processing Record 24 of Set 4 | barranca
# Processing Record 25 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 4 | quesnel
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | rurrenabaque
# Processing Record 29 of Set 4 | chuy
# Processing Record 30 of Set 4 | slave lake
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | marzuq
# Processing Record 33 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | saint anthony
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | yellowknife
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | camacari
# Processing Record 40 of Set 4 | salalah
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | hofn
# Processing Record 43 of Set 4 | piranhas
# Processing Record 44 of Set 4 | saint-philippe
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | ust-omchug
# Processing Record 47 of Set 4 | bezhetsk
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | nome
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | comodoro rivadavia
# Processing Record 2 of Set 5 | poum
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | ngunguru
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | burica
# City not found. Skipping...
# Processing Record 7 of Set 5 | cabinda
# Processing Record 8 of Set 5 | mikuni
# Processing Record 9 of Set 5 | galle
# Processing Record 10 of Set 5 | seabra
# Processing Record 11 of Set 5 | nabire
# Processing Record 12 of Set 5 | illora
# Processing Record 13 of Set 5 | mpulungu
# Processing Record 14 of Set 5 | carnot
# Processing Record 15 of Set 5 | antsohihy
# Processing Record 16 of Set 5 | kasongo-lunda
# Processing Record 17 of Set 5 | richards bay
# Processing Record 18 of Set 5 | skovde
# City not found. Skipping...
# Processing Record 19 of Set 5 | mlonggo
# Processing Record 20 of Set 5 | khash
# Processing Record 21 of Set 5 | tartus
# Processing Record 22 of Set 5 | elizabeth city
# Processing Record 23 of Set 5 | carutapera
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | kongolo
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 5 | hamilton
# Processing Record 28 of Set 5 | tunceli
# Processing Record 29 of Set 5 | emborion
# Processing Record 30 of Set 5 | anamur
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | pedro juan caballero
# Processing Record 33 of Set 5 | alyangula
# Processing Record 34 of Set 5 | rodino
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | abu kamal
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | pachino
# Processing Record 42 of Set 5 | cape town
# Processing Record 43 of Set 5 | te anau
# Processing Record 44 of Set 5 | mosetse
# Processing Record 45 of Set 5 | phan thiet
# Processing Record 46 of Set 5 | geraldton
# Processing Record 47 of Set 5 | mendeleyevsk
# Processing Record 48 of Set 5 | lazo
# Processing Record 49 of Set 5 | villa rica
# Processing Record 50 of Set 5 | bulawayo
# Processing Record 1 of Set 6 | dali
# Processing Record 2 of Set 6 | sooke
# Processing Record 3 of Set 6 | smithers
# Processing Record 4 of Set 6 | rio grande
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | nador
# Processing Record 7 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 6 | cuajinicuilapa
# Processing Record 9 of Set 6 | katherine
# Processing Record 10 of Set 6 | along
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | chernyshevskiy
# Processing Record 13 of Set 6 | aktas
# Processing Record 14 of Set 6 | qaqortoq
# Processing Record 15 of Set 6 | ajdabiya
# Processing Record 16 of Set 6 | moussoro
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | caninde
# Processing Record 19 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 6 | svetlaya
# Processing Record 21 of Set 6 | bhabua
# Processing Record 22 of Set 6 | macon
# Processing Record 23 of Set 6 | orotukan
# Processing Record 24 of Set 6 | san quintin
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | san patricio
# Processing Record 27 of Set 6 | salinas
# Processing Record 28 of Set 6 | hutang
# Processing Record 29 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 30 of Set 6 | krasnoarmeysk
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | yarmouth
# Processing Record 33 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 6 | port hawkesbury
# Processing Record 35 of Set 6 | yuli
# Processing Record 36 of Set 6 | koutiala
# Processing Record 37 of Set 6 | olafsvik
# Processing Record 38 of Set 6 | sarakhs
# Processing Record 39 of Set 6 | bolitoc
# Processing Record 40 of Set 6 | lazaro cardenas
# Processing Record 41 of Set 6 | great bend
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | riyadh
# Processing Record 44 of Set 6 | chegdomyn
# Processing Record 45 of Set 6 | charleston
# Processing Record 46 of Set 6 | biak
# Processing Record 47 of Set 6 | bria
# Processing Record 48 of Set 6 | golubitskaya
# Processing Record 49 of Set 6 | andros town
# Processing Record 50 of Set 6 | natal
# Processing Record 1 of Set 7 | sfantu gheorghe
# Processing Record 2 of Set 7 | nuevitas
# Processing Record 3 of Set 7 | shangqiu
# Processing Record 4 of Set 7 | thouars
# Processing Record 5 of Set 7 | yumen
# Processing Record 6 of Set 7 | aden
# Processing Record 7 of Set 7 | axim
# Processing Record 8 of Set 7 | luwuk
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | hanzhong
# Processing Record 13 of Set 7 | betma
# Processing Record 14 of Set 7 | koidu
# Processing Record 15 of Set 7 | eyl
# Processing Record 16 of Set 7 | road town
# Processing Record 17 of Set 7 | najran
# Processing Record 18 of Set 7 | boulder city
# Processing Record 19 of Set 7 | gamba
# Processing Record 20 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 7 | tigil
# Processing Record 22 of Set 7 | santa vitoria do palmar
# Processing Record 23 of Set 7 | union hidalgo
# Processing Record 24 of Set 7 | kirakira
# Processing Record 25 of Set 7 | shache
# Processing Record 26 of Set 7 | waingapu
# Processing Record 27 of Set 7 | westport
# Processing Record 28 of Set 7 | severo-kurilsk
# Processing Record 29 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 7 | necochea
# Processing Record 31 of Set 7 | sun city west
# Processing Record 32 of Set 7 | hudiksvall
# Processing Record 33 of Set 7 | baculin
# Processing Record 34 of Set 7 | vao
# Processing Record 35 of Set 7 | honningsvag
# Processing Record 36 of Set 7 | ambon
# Processing Record 37 of Set 7 | las matas de farfan
# Processing Record 38 of Set 7 | bukama
# Processing Record 39 of Set 7 | bad aussee
# Processing Record 40 of Set 7 | japura
# Processing Record 41 of Set 7 | vieux-habitants
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | krasnoarmeyskoye
# Processing Record 44 of Set 7 | tiznit
# Processing Record 45 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 46 of Set 7 | trinidad
# Processing Record 47 of Set 7 | yulara
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | araguaina
# Processing Record 50 of Set 7 | almeirim
# Processing Record 1 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 2 of Set 8 | bataipora
# Processing Record 3 of Set 8 | mitsamiouli
# Processing Record 4 of Set 8 | nambucca heads
# Processing Record 5 of Set 8 | saint-leu
# Processing Record 6 of Set 8 | nishihara
# Processing Record 7 of Set 8 | methoni
# Processing Record 8 of Set 8 | angoram
# Processing Record 9 of Set 8 | redmond
# Processing Record 10 of Set 8 | karachi
# Processing Record 11 of Set 8 | provideniya
# Processing Record 12 of Set 8 | luderitz
# Processing Record 13 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 8 | visnes
# Processing Record 15 of Set 8 | aksu
# Processing Record 16 of Set 8 | boende
# Processing Record 17 of Set 8 | atascocita
# Processing Record 18 of Set 8 | kiunga
# Processing Record 19 of Set 8 | lompoc
# Processing Record 20 of Set 8 | pisco
# Processing Record 21 of Set 8 | haapiti
# Processing Record 22 of Set 8 | bayir
# Processing Record 23 of Set 8 | sistranda
# Processing Record 24 of Set 8 | kununurra
# Processing Record 25 of Set 8 | raga
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | plettenberg bay
# Processing Record 28 of Set 8 | behbahan
# Processing Record 29 of Set 8 | arawa
# Processing Record 30 of Set 8 | san ramon
# Processing Record 31 of Set 8 | huanren
# Processing Record 32 of Set 8 | valparaiso
# Processing Record 33 of Set 8 | olkhovatka
# Processing Record 34 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 8 | gisborne
# Processing Record 36 of Set 8 | anadyr
# Processing Record 37 of Set 8 | linden
# Processing Record 38 of Set 8 | vestmannaeyjar
# Processing Record 39 of Set 8 | ahipara
# Processing Record 40 of Set 8 | grand gaube
# Processing Record 41 of Set 8 | egvekinot
# Processing Record 42 of Set 8 | tecolutilla
# Processing Record 43 of Set 8 | birjand
# Processing Record 44 of Set 8 | samarai
# Processing Record 45 of Set 8 | baykit
# Processing Record 46 of Set 8 | valdivia
# Processing Record 47 of Set 8 | naze
# Processing Record 48 of Set 8 | saint-ambroise
# Processing Record 49 of Set 8 | jurm
# Processing Record 50 of Set 8 | palmer
# Processing Record 1 of Set 9 | zakamensk
# Processing Record 2 of Set 9 | kunashak
# Processing Record 3 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 9 | aconibe
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | anupgarh
# Processing Record 7 of Set 9 | arman
# Processing Record 8 of Set 9 | hangal
# Processing Record 9 of Set 9 | kozhva
# Processing Record 10 of Set 9 | tubuala
# Processing Record 11 of Set 9 | vila velha
# Processing Record 12 of Set 9 | chizhou
# Processing Record 13 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 14 of Set 9 | venado tuerto
# Processing Record 15 of Set 9 | semey
# Processing Record 16 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 17 of Set 9 | gat
# Processing Record 18 of Set 9 | izazi
# Processing Record 19 of Set 9 | ust-nera
# Processing Record 20 of Set 9 | charters towers
# Processing Record 21 of Set 9 | lakatoro
# Processing Record 22 of Set 9 | pontevedra
# Processing Record 23 of Set 9 | puerto escondido
# Processing Record 24 of Set 9 | dera bugti
# Processing Record 25 of Set 9 | qostanay
# Processing Record 26 of Set 9 | conde
# Processing Record 27 of Set 9 | minab
# Processing Record 28 of Set 9 | puerto baquerizo moreno
# Processing Record 29 of Set 9 | half moon bay
# Processing Record 30 of Set 9 | sioux lookout
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | tessalit
# Processing Record 33 of Set 9 | tevaitoa
# Processing Record 34 of Set 9 | cauquenes
# Processing Record 35 of Set 9 | sao joao da barra
# Processing Record 36 of Set 9 | samarinda
# Processing Record 37 of Set 9 | kantabanji
# Processing Record 38 of Set 9 | asau
# Processing Record 39 of Set 9 | abaza
# Processing Record 40 of Set 9 | merauke
# Processing Record 41 of Set 9 | ambulu
# Processing Record 42 of Set 9 | zaozerne
# Processing Record 43 of Set 9 | kande
# Processing Record 44 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 45 of Set 9 | karratha
# Processing Record 46 of Set 9 | bonavista
# Processing Record 47 of Set 9 | todos santos
# Processing Record 48 of Set 9 | tezu
# Processing Record 49 of Set 9 | roscrea
# Processing Record 50 of Set 9 | tres arroyos
# Processing Record 1 of Set 10 | kavaratti
# Processing Record 2 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 10 | antofagasta
# Processing Record 4 of Set 10 | iqaluit
# Processing Record 5 of Set 10 | saldanha
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | tura
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | aitape
# Processing Record 11 of Set 10 | maldonado
# Processing Record 12 of Set 10 | ojinaga
# Processing Record 13 of Set 10 | san policarpo
# Processing Record 14 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 15 of Set 10 | zhireken
# Processing Record 16 of Set 10 | port-gentil
# Processing Record 17 of Set 10 | brae
# Processing Record 18 of Set 10 | tual
# Processing Record 19 of Set 10 | taloqan
# Processing Record 20 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 21 of Set 10 | rize
# Processing Record 22 of Set 10 | talara
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | nouadhibou
# Processing Record 25 of Set 10 | hualmay
# Processing Record 26 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 10 | maniitsoq
# Processing Record 28 of Set 10 | santo tomas
# Processing Record 29 of Set 10 | chapadinha
# Processing Record 30 of Set 10 | dubbo
# Processing Record 31 of Set 10 | mingshui
# Processing Record 32 of Set 10 | abnub
# Processing Record 33 of Set 10 | surt
# Processing Record 34 of Set 10 | waipawa
# Processing Record 35 of Set 10 | verkhnyaya inta
# Processing Record 36 of Set 10 | zheleznodorozhnyy
# Processing Record 37 of Set 10 | amapa
# Processing Record 38 of Set 10 | podbrdo
# Processing Record 39 of Set 10 | mercedes
# Processing Record 40 of Set 10 | tombouctou
# Processing Record 41 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 10 | the pas
# Processing Record 43 of Set 10 | coihaique
# Processing Record 44 of Set 10 | weihe
# Processing Record 45 of Set 10 | bangkok
# Processing Record 46 of Set 10 | peterhead
# Processing Record 47 of Set 10 | arlit
# Processing Record 48 of Set 10 | kigali
# Processing Record 49 of Set 10 | diamantino
# Processing Record 50 of Set 10 | troitskoye
# Processing Record 1 of Set 11 | oranjemund
# Processing Record 2 of Set 11 | kozachi laheri
# Processing Record 3 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 4 of Set 11 | inyonga
# Processing Record 5 of Set 11 | chuncheng
# Processing Record 6 of Set 11 | lesnoy
# Processing Record 7 of Set 11 | durant
# Processing Record 8 of Set 11 | yuancheng
# Processing Record 9 of Set 11 | lufilufi
# Processing Record 10 of Set 11 | businga
# Processing Record 11 of Set 11 | carballo
# Processing Record 12 of Set 11 | tabira
# Processing Record 13 of Set 11 | lishui
# Processing Record 14 of Set 11 | san jeronimo
# Processing Record 15 of Set 11 | ust-kuyga
# Processing Record 16 of Set 11 | pasni
# Processing Record 17 of Set 11 | betare oya
# Processing Record 18 of Set 11 | san isidro
# Processing Record 19 of Set 11 | mehamn
# Processing Record 20 of Set 11 | aloleng
# Processing Record 21 of Set 11 | channahon
# Processing Record 22 of Set 11 | ketchikan
# Processing Record 23 of Set 11 | khani
# Processing Record 24 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 25 of Set 11 | alekseyevka
# Processing Record 26 of Set 11 | chickasha
# Processing Record 27 of Set 11 | ust-ordynskiy
# Processing Record 28 of Set 11 | haines junction
# Processing Record 29 of Set 11 | the valley
# Processing Record 30 of Set 11 | kutina
# Processing Record 31 of Set 11 | acapulco
# Processing Record 32 of Set 11 | zhigansk
# Processing Record 33 of Set 11 | santa cruz de tenerife
# Processing Record 34 of Set 11 | arua
# Processing Record 35 of Set 11 | oda
# Processing Record 36 of Set 11 | candelaria
# Processing Record 37 of Set 11 | khandyga
# Processing Record 38 of Set 11 | banamba
# Processing Record 39 of Set 11 | ponta delgada
# Processing Record 40 of Set 11 | gorontalo
# Processing Record 41 of Set 11 | hay river
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | diego de almagro
# Processing Record 44 of Set 11 | sungairaya
# Processing Record 45 of Set 11 | launceston
# Processing Record 46 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 11 | chapada dos guimaraes
# Processing Record 48 of Set 11 | pimentel
# Processing Record 49 of Set 11 | puerto narino
# Processing Record 50 of Set 11 | quatre cocos
# Processing Record 1 of Set 12 | vylgort
# City not found. Skipping...
# Processing Record 2 of Set 12 | faya
# Processing Record 3 of Set 12 | nikel
# Processing Record 4 of Set 12 | mandalgovi
# Processing Record 5 of Set 12 | kita
# Processing Record 6 of Set 12 | camacha
# Processing Record 7 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 12 | xichang
# Processing Record 9 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 10 of Set 12 | mount isa
# Processing Record 11 of Set 12 | kadoshkino
# Processing Record 12 of Set 12 | fort nelson
# Processing Record 13 of Set 12 | batemans bay
# Processing Record 14 of Set 12 | lucea
# Processing Record 15 of Set 12 | zelenogorskiy
# Processing Record 16 of Set 12 | metro
# Processing Record 17 of Set 12 | hami
# Processing Record 18 of Set 12 | matiri
# Processing Record 19 of Set 12 | flin flon
# Processing Record 20 of Set 12 | erenhot
# Processing Record 21 of Set 12 | praia da vitoria
# Processing Record 22 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 23 of Set 12 | timbiqui
# Processing Record 24 of Set 12 | bauta
# Processing Record 25 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 12 | portland
# Processing Record 27 of Set 12 | marmaron
# City not found. Skipping...
# Processing Record 28 of Set 12 | upata
# Processing Record 29 of Set 12 | batamshinskiy
# Processing Record 30 of Set 12 | cayenne
# Processing Record 31 of Set 12 | qurbus
# Processing Record 32 of Set 12 | cavalcante
# Processing Record 33 of Set 12 | balkanabat
# Processing Record 34 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 12 | madang
# Processing Record 36 of Set 12 | sampit
# Processing Record 37 of Set 12 | berlevag
# Processing Record 38 of Set 12 | florianopolis
# Processing Record 39 of Set 12 | baglan
# Processing Record 40 of Set 12 | yarim
# Processing Record 41 of Set 12 | kendari
# Processing Record 42 of Set 12 | torit
# Processing Record 43 of Set 12 | santa cruz cabralia
# Processing Record 44 of Set 12 | lorengau
# Processing Record 45 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 12 | iskateley
# Processing Record 47 of Set 12 | hervey bay
# Processing Record 48 of Set 12 | smolenka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -14.98,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'GL',
#   'Date': '2021-01-27 15:49:39'},
#  {'City': 'Male',
#   'Lat': 4.1748,
#   'Lng': 73.5089,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MV',
#   'Date': '2021-01-27 15:49:39'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 30.99,
#   'Humidity': 65,
#   'Cloudiness': 92,
#   'Wind Speed': 11.99,
#   'Country': 'US',
#   'Date': '2021-01-27 15:47:09'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Date': '2021-01-27 15:48:19'},
#  {'City': 'Dawlatabad',
#   'Lat': 36.4141,
#   'Lng': 64.9053,
#   'Max Temp': 40.53,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 3.38,
#   'Country': 'AF',
#   'Date': '2021-01-27 15:49:40'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 79.77,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 14.65,
#   'Country': 'PF',
#   'Date': '2021-01-27 15:49:40'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 71.6,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Date': '2021-01-27 15:45:34'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': '2021-01-27 15:49:41'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 57.04,
#   'Humidity': 86,
#   'Cloudiness': 2,
#   'Wind Speed': 9.86,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:49:41'},
#  {'City': 'Kuybysheve',
#   'Lat': 47.358,
#   'Lng': 36.6491,
#   'Max Temp': 43.39,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 18.75,
#   'Country': 'UA',
#   'Date': '2021-01-27 15:49:41'},
#  {'City': 'Etchoropo',
#   'Lat': 26.7667,
#   'Lng': -109.6667,
#   'Max Temp': 55.8,
#   'Humidity': 50,
#   'Cloudiness': 66,
#   'Wind Speed': 13.76,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:49:41'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 53.01,
#   'Humidity': 76,
#   'Cloudiness': 73,
#   'Wind Speed': 23,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:49:41'},
#  {'City': 'Rio Bananal',
#   'Lat': -19.265,
#   'Lng': -40.3333,
#   'Max Temp': 87.31,
#   'Humidity': 46,
#   'Cloudiness': 51,
#   'Wind Speed': 4.76,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:49:42'},
#  {'City': 'Bestobe',
#   'Lat': 52.4994,
#   'Lng': 73.0975,
#   'Max Temp': 21.45,
#   'Humidity': 96,
#   'Cloudiness': 72,
#   'Wind Speed': 13.18,
#   'Country': 'KZ',
#   'Date': '2021-01-27 15:49:42'},
#  {'City': 'Buin',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 84,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CL',
#   'Date': '2021-01-27 15:49:42'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 64.27,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 13.8,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:49:42'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 60.26,
#   'Humidity': 66,
#   'Cloudiness': 98,
#   'Wind Speed': 8.75,
#   'Country': 'CL',
#   'Date': '2021-01-27 15:49:42'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 58.51,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:49:43'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.4,
#   'Humidity': 50,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:49:43'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.32,
#   'Humidity': 73,
#   'Cloudiness': 71,
#   'Wind Speed': 10.22,
#   'Country': 'PG',
#   'Date': '2021-01-27 15:49:43'},
#  {'City': 'Morro Bay',
#   'Lat': 35.3658,
#   'Lng': -120.8499,
#   'Max Temp': 50,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2021-01-27 15:45:43'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 69.8,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-01-27 15:49:43'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 44.6,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 31.07,
#   'Country': 'CL',
#   'Date': '2021-01-27 15:49:44'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 78.42,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 4.81,
#   'Country': 'SB',
#   'Date': '2021-01-27 15:49:44'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 69.01,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 5.99,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:49:44'},
#  {'City': 'Shenjiamen',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp': 45.97,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:49:44'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 66,
#   'Humidity': 87,
#   'Cloudiness': 15,
#   'Wind Speed': 1.54,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:49:45'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 71.6,
#   'Humidity': 40,
#   'Cloudiness': 79,
#   'Wind Speed': 9.22,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:49:45'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 51.8,
#   'Humidity': 37,
#   'Cloudiness': 40,
#   'Wind Speed': 26.46,
#   'Country': 'AR',
#   'Date': '2021-01-27 15:49:45'},
#  {'City': 'Ilesha',
#   'Lat': 7.1371,
#   'Lng': 5.2583,
#   'Max Temp': 97.02,
#   'Humidity': 18,
#   'Cloudiness': 94,
#   'Wind Speed': 5.68,
#   'Country': 'NG',
#   'Date': '2021-01-27 15:49:45'},
#  {'City': 'Wakkanai',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 21.24,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 33.46,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:49:46'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': '2021-01-27 15:49:46'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -40.67,
#   'Humidity': 80,
#   'Cloudiness': 77,
#   'Wind Speed': 2.48,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:46'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 55,
#   'Humidity': 65,
#   'Cloudiness': 83,
#   'Wind Speed': 1.39,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:49:46'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 73.99,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-01-27 15:49:47'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.7,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.94,
#   'Country': 'MV',
#   'Date': '2021-01-27 15:49:47'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.01,
#   'Humidity': 92,
#   'Cloudiness': 39,
#   'Wind Speed': 3,
#   'Country': 'EC',
#   'Date': '2021-01-27 15:49:47'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 74.44,
#   'Humidity': 72,
#   'Cloudiness': 76,
#   'Wind Speed': 19.17,
#   'Country': 'SO',
#   'Date': '2021-01-27 15:49:47'},
#  {'City': 'Charagua',
#   'Lat': -19.8,
#   'Lng': -63.2167,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 6.8,
#   'Country': 'BO',
#   'Date': '2021-01-27 15:49:47'},
#  {'City': 'Sarahan',
#   'Lat': 31.5167,
#   'Lng': 77.8,
#   'Max Temp': 34.88,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 7.49,
#   'Country': 'IN',
#   'Date': '2021-01-27 15:49:48'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 24.53,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Country': 'GL',
#   'Date': '2021-01-27 15:49:48'},
#  {'City': 'Kombissiri',
#   'Lat': 12.0656,
#   'Lng': -1.3375,
#   'Max Temp': 95,
#   'Humidity': 6,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'BF',
#   'Date': '2021-01-27 15:49:48'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 55,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 14.5,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:49:49'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 64,
#   'Humidity': 86,
#   'Cloudiness': 30,
#   'Wind Speed': 10.4,
#   'Country': 'HK',
#   'Date': '2021-01-27 15:45:12'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 1.14,
#   'Country': 'TO',
#   'Date': '2021-01-27 15:49:49'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.13,
#   'Humidity': 79,
#   'Cloudiness': 17,
#   'Wind Speed': 10.85,
#   'Country': 'KI',
#   'Date': '2021-01-27 15:49:49'},
#  {'City': 'Soubre',
#   'Lat': 5.7856,
#   'Lng': -6.6083,
#   'Max Temp': 92.66,
#   'Humidity': 38,
#   'Cloudiness': 53,
#   'Wind Speed': 2.66,
#   'Country': 'CI',
#   'Date': '2021-01-27 15:49:49'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.95,
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 15.08,
#   'Country': 'PF',
#   'Date': '2021-01-27 15:49:50'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 84.2,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 24.16,
#   'Country': 'BB',
#   'Date': '2021-01-27 15:49:50'},
#  {'City': 'Ternovskaya',
#   'Lat': 45.8542,
#   'Lng': 40.4086,
#   'Max Temp': 40.32,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.9,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:50'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 71.01,
#   'Humidity': 52,
#   'Cloudiness': 82,
#   'Wind Speed': 1.99,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:49:36'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 83.86,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 6.53,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:49:51'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 75.97,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 17.67,
#   'Country': 'TC',
#   'Date': '2021-01-27 15:49:51'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 42.75,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 6.46,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:49:51'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': -39.82,
#   'Humidity': 81,
#   'Cloudiness': 38,
#   'Wind Speed': 2.98,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:52'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 33.8,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 24.61,
#   'Country': 'NO',
#   'Date': '2021-01-27 15:49:52'},
#  {'City': 'Bourail',
#   'Lat': -21.5667,
#   'Lng': 165.4833,
#   'Max Temp': 74.71,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 2.77,
#   'Country': 'NC',
#   'Date': '2021-01-27 15:49:52'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'PF',
#   'Date': '2021-01-27 15:49:52'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 22,
#   'Wind Speed': 11.5,
#   'Country': 'NA',
#   'Date': '2021-01-27 15:49:52'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 79,
#   'Humidity': 80,
#   'Cloudiness': 11,
#   'Wind Speed': 1.99,
#   'Country': 'MU',
#   'Date': '2021-01-27 15:49:53'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 16.77,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.08,
#   'Country': 'GL',
#   'Date': '2021-01-27 15:49:53'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 93.2,
#   'Humidity': 45,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:49:53'},
#  {'City': 'Voh',
#   'Lat': -20.9667,
#   'Lng': 164.7,
#   'Max Temp': 74.44,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 3.87,
#   'Country': 'NC',
#   'Date': '2021-01-27 15:49:53'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -28.44,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 8.5,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:54'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 86.85,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 12.3,
#   'Country': 'ML',
#   'Date': '2021-01-27 15:49:54'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': -10.5,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:54'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': '2021-01-27 15:49:54'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 73.4,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-01-27 15:49:54'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 53.01,
#   'Humidity': 76,
#   'Cloudiness': 76,
#   'Wind Speed': 23,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:49:55'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 87.01,
#   'Humidity': 58,
#   'Cloudiness': 30,
#   'Wind Speed': 16.33,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:49:55'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -21.15,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.78,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:55'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 77.11,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:49:55'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 75.97,
#   'Humidity': 75,
#   'Cloudiness': 72,
#   'Wind Speed': 1.81,
#   'Country': 'LK',
#   'Date': '2021-01-27 15:49:55'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 82.58,
#   'Humidity': 73,
#   'Cloudiness': 12,
#   'Wind Speed': 7.05,
#   'Country': 'CI',
#   'Date': '2021-01-27 15:49:56'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 41,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:49:56'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 52,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-01-27 15:47:59'},
#  {'City': 'Manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 77.4,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 12.08,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:49:57'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -20.58,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.2,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:57'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 89.6,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:46:03'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 34,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:57'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:49:57'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 19.38,
#   'Humidity': 92,
#   'Cloudiness': 22,
#   'Wind Speed': 10.4,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:49:58'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:49:58'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 17.6,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'IS',
#   'Date': '2021-01-27 15:49:59'},
#  {'City': 'Gewane',
#   'Lat': 10.1664,
#   'Lng': 40.6453,
#   'Max Temp': 80.2,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 9.89,
#   'Country': 'ET',
#   'Date': '2021-01-27 15:49:59'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -23.8,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 2.15,
#   'Country': 'US',
#   'Date': '2021-01-27 15:49:40'},
#  {'City': 'Harsin',
#   'Lat': 34.2721,
#   'Lng': 47.5861,
#   'Max Temp': 46.4,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'IR',
#   'Date': '2021-01-27 15:49:59'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -24.79,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:49:59'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 53.01,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 23,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:50:00'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'PT',
#   'Date': '2021-01-27 15:50:00'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 39.2,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:00'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 17.82,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 29.51,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:01'},
#  {'City': 'Belaya Gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': -24.43,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:01'},
#  {'City': 'Tarko-Sale',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': -41.24,
#   'Humidity': 80,
#   'Cloudiness': 26,
#   'Wind Speed': 9.46,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:02'},
#  {'City': 'Matamoros',
#   'Lat': 25.5333,
#   'Lng': -103.25,
#   'Max Temp': 52,
#   'Humidity': 28,
#   'Cloudiness': 83,
#   'Wind Speed': 7,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:50:03'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 78.15,
#   'Humidity': 49,
#   'Cloudiness': 54,
#   'Wind Speed': 7.9,
#   'Country': 'VE',
#   'Date': '2021-01-27 15:50:04'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -7.6,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:05'},
#  {'City': 'Portobelo',
#   'Lat': 9.55,
#   'Lng': -79.65,
#   'Max Temp': 86,
#   'Humidity': 99,
#   'Cloudiness': 88,
#   'Wind Speed': 11.61,
#   'Country': 'PA',
#   'Date': '2021-01-27 15:50:05'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 0.4,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:06'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 22.55,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0.43,
#   'Country': 'GL',
#   'Date': '2021-01-27 15:50:06'},
#  {'City': 'Antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 79.48,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 2.39,
#   'Country': 'MG',
#   'Date': '2021-01-27 15:50:06'},
#  {'City': 'Shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 74.35,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'BW',
#   'Date': '2021-01-27 15:50:06'},
#  {'City': 'Olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:06'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 48.2,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:50:07'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 63.75,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.56,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:07'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 62.01,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:47:15'},
#  {'City': 'Mineiros',
#   'Lat': -17.5694,
#   'Lng': -52.5511,
#   'Max Temp': 80.51,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:46:53'},
#  {'City': 'Ormara',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 68.47,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34,
#   'Country': 'PK',
#   'Date': '2021-01-27 15:50:08'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 76.33,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 11.32,
#   'Country': 'LK',
#   'Date': '2021-01-27 15:50:08'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': -2.2,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:08'},
#  {'City': 'Luau',
#   'Lat': -10.7073,
#   'Lng': 22.2247,
#   'Max Temp': 73,
#   'Humidity': 91,
#   'Cloudiness': 91,
#   'Wind Speed': 2.95,
#   'Country': 'AO',
#   'Date': '2021-01-27 15:50:08'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'CK',
#   'Date': '2021-01-27 15:50:08'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -26.57,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:09'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -31,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:09'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': -43.06,
#   'Humidity': 78,
#   'Cloudiness': 3,
#   'Wind Speed': 1.1,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:09'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 26.01,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 10,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:09'},
#  {'City': 'Changde',
#   'Lat': 29.0464,
#   'Lng': 111.6783,
#   'Max Temp': 45,
#   'Humidity': 67,
#   'Cloudiness': 51,
#   'Wind Speed': 5.99,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:48:32'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 76.44,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 3.56,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:50:10'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -20.58,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:10'},
#  {'City': 'Eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 43,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:10'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 79,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'MY',
#   'Date': '2021-01-27 15:49:10'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'ES',
#   'Date': '2021-01-27 15:50:11'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 33.01,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-01-27 15:46:16'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -25.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:45:12'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 62.2,
#   'Humidity': 80,
#   'Cloudiness': 67,
#   'Wind Speed': 31.7,
#   'Country': 'PT',
#   'Date': '2021-01-27 15:50:11'},
#  {'City': 'Aguimes',
#   'Lat': 27.9054,
#   'Lng': -15.4461,
#   'Max Temp': 73.99,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ES',
#   'Date': '2021-01-27 15:50:11'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -37.73,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 0.92,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:12'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -2.94,
#   'Humidity': 89,
#   'Cloudiness': 84,
#   'Wind Speed': 12.41,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:12'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 32,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02,
#   'Country': 'IS',
#   'Date': '2021-01-27 15:50:12'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -14.8,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:13'},
#  {'City': 'Zabid',
#   'Lat': 14.1951,
#   'Lng': 43.3152,
#   'Max Temp': 77.11,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 14.67,
#   'Country': 'YE',
#   'Date': '2021-01-27 15:50:13'},
#  {'City': 'Northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 52,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'GB',
#   'Date': '2021-01-27 15:50:13'},
#  {'City': 'Tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 78.4,
#   'Humidity': 32,
#   'Cloudiness': 59,
#   'Wind Speed': 1.88,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:50:13'},
#  {'City': 'Ucluelet',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 39,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:13'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 66.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:50:14'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -26.16,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:14'},
#  {'City': 'Goulburn',
#   'Lat': -34.75,
#   'Lng': 149.7167,
#   'Max Temp': 60.01,
#   'Humidity': 95,
#   'Cloudiness': 89,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:14'},
#  {'City': 'Wairoa',
#   'Lat': -39.0333,
#   'Lng': 177.3667,
#   'Max Temp': 65.66,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.17,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:50:14'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -11.2,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:14'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 80.78,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Country': 'PG',
#   'Date': '2021-01-27 15:50:15'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 8.6,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'SJ',
#   'Date': '2021-01-27 15:50:15'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 27,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:15'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 24.8,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:15'},
#  {'City': 'Biltine',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 87.49,
#   'Humidity': 12,
#   'Cloudiness': 38,
#   'Wind Speed': 10.4,
#   'Country': 'TD',
#   'Date': '2021-01-27 15:50:16'},
#  {'City': 'Umarizal',
#   'Lat': -5.9906,
#   'Lng': -37.8144,
#   'Max Temp': 95.49,
#   'Humidity': 32,
#   'Cloudiness': 52,
#   'Wind Speed': 7.07,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:16'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': -26.84,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.77,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:16'},
#  {'City': 'Alto Araguaia',
#   'Lat': -17.3147,
#   'Lng': -53.2153,
#   'Max Temp': 82.54,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:16'},
#  {'City': 'Kabinda',
#   'Lat': -6.1333,
#   'Lng': 24.4833,
#   'Max Temp': 77.32,
#   'Humidity': 77,
#   'Cloudiness': 66,
#   'Wind Speed': 3.42,
#   'Country': 'CD',
#   'Date': '2021-01-27 15:50:17'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -30.95,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.81,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:17'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 17.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:17'},
#  {'City': 'Sangar',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': -54.18,
#   'Humidity': 69,
#   'Cloudiness': 94,
#   'Wind Speed': 2.19,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:18'},
#  {'City': 'Inuvik',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': -11.2,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:18'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -11.2,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:18'},
#  {'City': 'Santa Maria',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:46:27'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:50:19'},
#  {'City': 'Bairiki',
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'KI',
#   'Date': '2021-01-27 15:50:19'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 61,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'ES',
#   'Date': '2021-01-27 15:50:19'},
#  {'City': 'Barranca',
#   'Lat': -10.75,
#   'Lng': -77.7667,
#   'Max Temp': 76.12,
#   'Humidity': 66,
#   'Cloudiness': 91,
#   'Wind Speed': 11.21,
#   'Country': 'PE',
#   'Date': '2021-01-27 15:50:19'},
#  {'City': 'Quesnel',
#   'Lat': 52.9999,
#   'Lng': -122.5029,
#   'Max Temp': 23,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:20'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 55.4,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:20'},
#  {'City': 'Rurrenabaque',
#   'Lat': -14.4413,
#   'Lng': -67.5278,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BO',
#   'Date': '2021-01-27 15:50:20'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 81.43,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Country': 'UY',
#   'Date': '2021-01-27 15:50:20'},
#  {'City': 'Slave Lake',
#   'Lat': 55.2834,
#   'Lng': -114.769,
#   'Max Temp': 1.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:21'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 32,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:21'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 63.14,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Country': 'YE',
#   'Date': '2021-01-27 15:50:21'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 61.75,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'TL',
#   'Date': '2021-01-27 15:50:21'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 9,
#   'Humidity': 56,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:22'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -11,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:22'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 23.02,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:22'},
#  {'City': 'Camacari',
#   'Lat': -12.6975,
#   'Lng': -38.3242,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:22'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'OM',
#   'Date': '2021-01-27 15:50:23'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 55.98,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 4.99,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:50:23'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 28.4,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'IS',
#   'Date': '2021-01-27 15:50:23'},
#  {'City': 'Piranhas',
#   'Lat': -16.4269,
#   'Lng': -51.8222,
#   'Max Temp': 84.02,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:23'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'RE',
#   'Date': '2021-01-27 15:50:23'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 61,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2021-01-27 15:46:54'},
#  {'City': 'Ust-Omchug',
#   'Lat': 61.15,
#   'Lng': 149.6333,
#   'Max Temp': -30.01,
#   'Humidity': 79,
#   'Cloudiness': 30,
#   'Wind Speed': 5.06,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:24'},
#  {'City': 'Bezhetsk',
#   'Lat': 57.7851,
#   'Lng': 36.6965,
#   'Max Temp': 27.16,
#   'Humidity': 97,
#   'Cloudiness': 89,
#   'Wind Speed': 9.48,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:47:05'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:24'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 5,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:24'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 62.6,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:25'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 62.6,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Date': '2021-01-27 15:45:34'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 79.79,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 11.36,
#   'Country': 'NC',
#   'Date': '2021-01-27 15:50:25'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -19.39,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:25'},
#  {'City': 'Ngunguru',
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp': 66,
#   'Humidity': 87,
#   'Cloudiness': 22,
#   'Wind Speed': 4.43,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:50:25'},
#  {'City': 'Cabinda',
#   'Lat': -5.55,
#   'Lng': 12.2,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'AO',
#   'Date': '2021-01-27 15:50:26'},
#  {'City': 'Mikuni',
#   'Lat': 36.2171,
#   'Lng': 136.1519,
#   'Max Temp': 41,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:50:26'},
#  {'City': 'Galle',
#   'Lat': 6.0367,
#   'Lng': 80.217,
#   'Max Temp': 78.44,
#   'Humidity': 74,
#   'Cloudiness': 65,
#   'Wind Speed': 1.07,
#   'Country': 'LK',
#   'Date': '2021-01-27 15:50:26'},
#  {'City': 'Seabra',
#   'Lat': -12.4186,
#   'Lng': -41.7703,
#   'Max Temp': 82.89,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:27'},
#  {'City': 'Nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 77.14,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:50:27'},
#  {'City': 'Illora',
#   'Lat': 37.2877,
#   'Lng': -3.8811,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'ES',
#   'Date': '2021-01-27 15:50:27'},
#  {'City': 'Mpulungu',
#   'Lat': -8.7623,
#   'Lng': 31.1141,
#   'Max Temp': 75.47,
#   'Humidity': 71,
#   'Cloudiness': 85,
#   'Wind Speed': 0.74,
#   'Country': 'ZM',
#   'Date': '2021-01-27 15:50:27'},
#  {'City': 'Carnot',
#   'Lat': 4.9409,
#   'Lng': 15.8665,
#   'Max Temp': 96.87,
#   'Humidity': 16,
#   'Cloudiness': 98,
#   'Wind Speed': 7.09,
#   'Country': 'CF',
#   'Date': '2021-01-27 15:50:27'},
#  {'City': 'Antsohihy',
#   'Lat': -14.8796,
#   'Lng': 47.9875,
#   'Max Temp': 77.95,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 4.56,
#   'Country': 'MG',
#   'Date': '2021-01-27 15:50:28'},
#  {'City': 'Kasongo-Lunda',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 74.17,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 0.49,
#   'Country': 'CD',
#   'Date': '2021-01-27 15:50:28'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 75.25,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:50:28'},
#  {'City': 'Mlonggo',
#   'Lat': -6.5333,
#   'Lng': 110.7,
#   'Max Temp': 78.53,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 16.8,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:49:04'},
#  {'City': 'Khash',
#   'Lat': 28.2211,
#   'Lng': 61.2158,
#   'Max Temp': 44.94,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 6.04,
#   'Country': 'IR',
#   'Date': '2021-01-27 15:50:29'},
#  {'City': 'Tartus',
#   'Lat': 34.889,
#   'Lng': 35.8866,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'SY',
#   'Date': '2021-01-27 15:50:29'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:29'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 86.67,
#   'Humidity': 62,
#   'Cloudiness': 47,
#   'Wind Speed': 7.29,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:29'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 85.57,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 10.22,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:30'},
#  {'City': 'Kongolo',
#   'Lat': -5.3833,
#   'Lng': 27,
#   'Max Temp': 80.06,
#   'Humidity': 80,
#   'Cloudiness': 59,
#   'Wind Speed': 1.7,
#   'Country': 'CD',
#   'Date': '2021-01-27 15:50:30'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 33.01,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:12'},
#  {'City': 'Tunceli',
#   'Lat': 39.1083,
#   'Lng': 39.5471,
#   'Max Temp': 42.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'TR',
#   'Date': '2021-01-27 15:50:30'},
#  {'City': 'Emborion',
#   'Lat': 40.4833,
#   'Lng': 21.55,
#   'Max Temp': 32,
#   'Humidity': 51,
#   'Cloudiness': 73,
#   'Wind Speed': 10.36,
#   'Country': 'GR',
#   'Date': '2021-01-27 15:50:31'},
#  {'City': 'Anamur',
#   'Lat': 36.0751,
#   'Lng': 32.8369,
#   'Max Temp': 55.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'TR',
#   'Date': '2021-01-27 15:48:29'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'NU',
#   'Date': '2021-01-27 15:50:31'},
#  {'City': 'Pedro Juan Caballero',
#   'Lat': -22.5472,
#   'Lng': -55.7333,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 11.27,
#   'Country': 'PY',
#   'Date': '2021-01-27 15:50:32'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:32'},
#  {'City': 'Rodino',
#   'Lat': 52.5,
#   'Lng': 80.25,
#   'Max Temp': 24.33,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 11.97,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:32'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:48:58'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'CL',
#   'Date': '2021-01-27 15:45:51'},
#  {'City': 'Abu Kamal',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 56.91,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 13.02,
#   'Country': 'SY',
#   'Date': '2021-01-27 15:50:33'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 76.77,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 8.68,
#   'Country': 'CV',
#   'Date': '2021-01-27 15:50:33'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 53.01,
#   'Humidity': 76,
#   'Cloudiness': 33,
#   'Wind Speed': 18.01,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:50:34'},
#  {'City': 'Pachino',
#   'Lat': 36.7186,
#   'Lng': 15.0907,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 66,
#   'Wind Speed': 9.22,
#   'Country': 'IT',
#   'Date': '2021-01-27 15:50:34'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 72,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 26.46,
#   'Country': 'ZA',
#   'Date': '2021-01-27 15:46:57'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 48.29,
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 7.78,
#   'Country': 'NZ',
#   'Date': '2021-01-27 15:50:34'},
#  {'City': 'Mosetse',
#   'Lat': -20.75,
#   'Lng': 26.65,
#   'Max Temp': 79.86,
#   'Humidity': 61,
#   'Cloudiness': 55,
#   'Wind Speed': 6.46,
#   'Country': 'BW',
#   'Date': '2021-01-27 15:50:34'},
#  {'City': 'Phan Thiet',
#   'Lat': 10.9333,
#   'Lng': 108.1,
#   'Max Temp': 72.75,
#   'Humidity': 86,
#   'Cloudiness': 21,
#   'Wind Speed': 9.82,
#   'Country': 'VN',
#   'Date': '2021-01-27 15:47:51'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:35'},
#  {'City': 'Mendeleyevsk',
#   'Lat': 55.9082,
#   'Lng': 52.2905,
#   'Max Temp': 21.2,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:35'},
#  {'City': 'Lazo',
#   'Lat': 43.3817,
#   'Lng': 133.9014,
#   'Max Temp': 1.06,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:35'},
#  {'City': 'Villa Rica',
#   'Lat': 33.7321,
#   'Lng': -84.9191,
#   'Max Temp': 52,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:36'},
#  {'City': 'Bulawayo',
#   'Lat': -20.15,
#   'Lng': 28.5833,
#   'Max Temp': 73.08,
#   'Humidity': 79,
#   'Cloudiness': 82,
#   'Wind Speed': 4.03,
#   'Country': 'ZW',
#   'Date': '2021-01-27 15:50:36'},
#  {'City': 'Dali',
#   'Lat': 25.7,
#   'Lng': 100.1833,
#   'Max Temp': 44.44,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 4.45,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:50:36'},
#  {'City': 'Sooke',
#   'Lat': 48.3746,
#   'Lng': -123.7276,
#   'Max Temp': 42.8,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:36'},
#  {'City': 'Smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 21.2,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:50:09'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:15'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 86,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'AO',
#   'Date': '2021-01-27 15:50:37'},
#  {'City': 'Nador',
#   'Lat': 35.174,
#   'Lng': -2.9287,
#   'Max Temp': 73.4,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'MA',
#   'Date': '2021-01-27 15:50:37'},
#  {'City': 'Cuajinicuilapa',
#   'Lat': 16.4667,
#   'Lng': -98.4167,
#   'Max Temp': 88.03,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 1.68,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:47:37'},
#  {'City': 'Katherine',
#   'Lat': -14.4667,
#   'Lng': 132.2667,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:50:38'},
#  {'City': 'Along',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 53.91,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'IN',
#   'Date': '2021-01-27 15:50:38'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 43,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:38'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': -45.8,
#   'Humidity': 81,
#   'Cloudiness': 33,
#   'Wind Speed': 1.74,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:38'},
#  {'City': 'Aktas',
#   'Lat': 49.7789,
#   'Lng': 72.9608,
#   'Max Temp': 22.33,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'KZ',
#   'Date': '2021-01-27 15:50:38'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 21.69,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 3.04,
#   'Country': 'GL',
#   'Date': '2021-01-27 15:50:39'},
#  {'City': 'Ajdabiya',
#   'Lat': 30.7554,
#   'Lng': 20.2263,
#   'Max Temp': 57.47,
#   'Humidity': 56,
#   'Cloudiness': 10,
#   'Wind Speed': 13.85,
#   'Country': 'LY',
#   'Date': '2021-01-27 15:50:39'},
#  {'City': 'Moussoro',
#   'Lat': 13.6408,
#   'Lng': 16.4901,
#   'Max Temp': 89.98,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 11.59,
#   'Country': 'TD',
#   'Date': '2021-01-27 15:50:39'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.87,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.78,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:50:39'},
#  {'City': 'Caninde',
#   'Lat': -4.3589,
#   'Lng': -39.3117,
#   'Max Temp': 95.13,
#   'Humidity': 34,
#   'Cloudiness': 37,
#   'Wind Speed': 8.25,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:50:39'},
#  {'City': 'Svetlaya',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp': 4.35,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:40'},
#  {'City': 'Bhabua',
#   'Lat': 25.05,
#   'Lng': 83.6167,
#   'Max Temp': 50.45,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 0.89,
#   'Country': 'IN',
#   'Date': '2021-01-27 15:46:16'},
#  {'City': 'Macon',
#   'Lat': 39.8667,
#   'Lng': -88.9668,
#   'Max Temp': 28.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:05'},
#  {'City': 'Orotukan',
#   'Lat': 62.2667,
#   'Lng': 151.7,
#   'Max Temp': -35.97,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:50:40'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 53.24,
#   'Humidity': 49,
#   'Cloudiness': 8,
#   'Wind Speed': 2.13,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:50:41'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 0.43,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'GL',
#   'Date': '2021-01-27 15:50:41'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 63,
#   'Humidity': 44,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'US',
# ...
#  {'City': 'Durant',
#   'Lat': 33.994,
#   'Lng': -96.3708,
#   'Max Temp': 37.4,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-01-27 15:51:30'},
#  {'City': 'Yuancheng',
#   'Lat': 36.652,
#   'Lng': 107.7896,
#   'Max Temp': 22.12,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 15.59,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:51:30'},
#  {'City': 'Lufilufi',
#   'Lat': -13.8745,
#   'Lng': -171.5986,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'WS',
#   'Date': '2021-01-27 15:51:30'},
#  {'City': 'Businga',
#   'Lat': 3.3333,
#   'Lng': 20.8833,
#   'Max Temp': 89.31,
#   'Humidity': 41,
#   'Cloudiness': 88,
#   'Wind Speed': 4.38,
#   'Country': 'CD',
#   'Date': '2021-01-27 15:51:30'},
#  {'City': 'Carballo',
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 60.01,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'ES',
#   'Date': '2021-01-27 15:51:30'},
#  {'City': 'Tabira',
#   'Lat': -7.5908,
#   'Lng': -37.5394,
#   'Max Temp': 93.38,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:51:31'},
#  {'City': 'Lishui',
#   'Lat': 28.4604,
#   'Lng': 119.9103,
#   'Max Temp': 50.29,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:51:31'},
#  {'City': 'San Jeronimo',
#   'Lat': -11.9472,
#   'Lng': -75.2829,
#   'Max Temp': 59.81,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 2.8,
#   'Country': 'PE',
#   'Date': '2021-01-27 15:51:31'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': -37.12,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 2.64,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:31'},
#  {'City': 'Pasni',
#   'Lat': 25.2631,
#   'Lng': 63.471,
#   'Max Temp': 67.87,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'PK',
#   'Date': '2021-01-27 15:51:31'},
#  {'City': 'Betare Oya',
#   'Lat': 5.6,
#   'Lng': 14.0833,
#   'Max Temp': 96.06,
#   'Humidity': 15,
#   'Cloudiness': 21,
#   'Wind Speed': 4.61,
#   'Country': 'CM',
#   'Date': '2021-01-27 15:51:32'},
#  {'City': 'San Isidro',
#   'Lat': -12.1167,
#   'Lng': -77.05,
#   'Max Temp': 71.01,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 3,
#   'Country': 'PE',
#   'Date': '2021-01-27 15:51:32'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 24.8,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 25.32,
#   'Country': 'NO',
#   'Date': '2021-01-27 15:51:32'},
#  {'City': 'Aloleng',
#   'Lat': 16.1307,
#   'Lng': 119.7824,
#   'Max Temp': 79.41,
#   'Humidity': 80,
#   'Cloudiness': 88,
#   'Wind Speed': 5.17,
#   'Country': 'PH',
#   'Date': '2021-01-27 15:51:32'},
#  {'City': 'Channahon',
#   'Lat': 41.4295,
#   'Lng': -88.2287,
#   'Max Temp': 27,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-01-27 15:51:32'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-01-27 15:51:33'},
#  {'City': 'Khani',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 60.8,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'GE',
#   'Date': '2021-01-27 15:51:33'},
#  {'City': 'Alekseyevka',
#   'Lat': 50.6309,
#   'Lng': 38.6903,
#   'Max Temp': 37.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.23,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:33'},
#  {'City': 'Chickasha',
#   'Lat': 35.0526,
#   'Lng': -97.9364,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-01-27 15:48:18'},
#  {'City': 'Ust-Ordynskiy',
#   'Lat': 52.805,
#   'Lng': 104.7508,
#   'Max Temp': -25.6,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:34'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': -27.4,
#   'Humidity': 68,
#   'Cloudiness': 45,
#   'Wind Speed': 1.14,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:51:34'},
#  {'City': 'The Valley',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'AI',
#   'Date': '2021-01-27 15:51:34'},
#  {'City': 'Kutina',
#   'Lat': 45.475,
#   'Lng': 16.7819,
#   'Max Temp': 39.2,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'HR',
#   'Date': '2021-01-27 15:51:34'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 82.24,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'MX',
#   'Date': '2021-01-27 15:47:07'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': -48.15,
#   'Humidity': 75,
#   'Cloudiness': 59,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:35'},
#  {'City': 'Santa Cruz De Tenerife',
#   'Lat': 28.4682,
#   'Lng': -16.2546,
#   'Max Temp': 69.8,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'ES',
#   'Date': '2021-01-27 15:51:35'},
#  {'City': 'Arua',
#   'Lat': 3.0201,
#   'Lng': 30.9111,
#   'Max Temp': 82.58,
#   'Humidity': 25,
#   'Cloudiness': 77,
#   'Wind Speed': 3.96,
#   'Country': 'UG',
#   'Date': '2021-01-27 15:51:35'},
#  {'City': 'Oda',
#   'Lat': 35.1833,
#   'Lng': 132.5,
#   'Max Temp': 43.27,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 8.5,
#   'Country': 'JP',
#   'Date': '2021-01-27 15:51:36'},
#  {'City': 'Candelaria',
#   'Lat': 13.9311,
#   'Lng': 121.4233,
#   'Max Temp': 75.99,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'PH',
#   'Date': '2021-01-27 15:51:37'},
#  {'City': 'Khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': -51.54,
#   'Humidity': 76,
#   'Cloudiness': 89,
#   'Wind Speed': 0.85,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:37'},
#  {'City': 'Banamba',
#   'Lat': 13.55,
#   'Lng': -7.45,
#   'Max Temp': 94.14,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 8.57,
#   'Country': 'ML',
#   'Date': '2021-01-27 15:51:37'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 66,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'PT',
#   'Date': '2021-01-27 15:51:37'},
#  {'City': 'Gorontalo',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 75.6,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:51:37'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': -11.2,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:47:26'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -23.8,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 2.33,
#   'Country': 'US',
#   'Date': '2021-01-27 15:51:38'},
#  {'City': 'Diego De Almagro',
#   'Lat': -26.3667,
#   'Lng': -70.05,
#   'Max Temp': 86.61,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 15.21,
#   'Country': 'CL',
#   'Date': '2021-01-27 15:48:25'},
#  {'City': 'Sungairaya',
#   'Lat': 0.7,
#   'Lng': 108.9,
#   'Max Temp': 77.41,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:51:38'},
#  {'City': 'Launceston',
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp': 53.01,
#   'Humidity': 76,
#   'Cloudiness': 87,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:51:39'},
#  {'City': 'Chapada Dos Guimaraes',
#   'Lat': -15.4606,
#   'Lng': -55.7497,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:51:39'},
#  {'City': 'Pimentel',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 75.16,
#   'Humidity': 69,
#   'Cloudiness': 21,
#   'Wind Speed': 10.76,
#   'Country': 'PE',
#   'Date': '2021-01-27 15:51:39'},
#  {'City': 'Puerto Narino',
#   'Lat': -3.7703,
#   'Lng': -70.3831,
#   'Max Temp': 92.62,
#   'Humidity': 49,
#   'Cloudiness': 87,
#   'Wind Speed': 1.79,
#   'Country': 'CO',
#   'Date': '2021-01-27 15:51:39'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': '2021-01-27 15:51:40'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 66.2,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'SA',
#   'Date': '2021-01-27 15:51:40'},
#  {'City': 'Nikel',
#   'Lat': 69.4128,
#   'Lng': 30.222,
#   'Max Temp': 21.2,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:40'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': -12.59,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 7.09,
#   'Country': 'MN',
#   'Date': '2021-01-27 15:51:06'},
#  {'City': 'Kita',
#   'Lat': 13.0349,
#   'Lng': -9.4895,
#   'Max Temp': 98.69,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Country': 'ML',
#   'Date': '2021-01-27 15:51:41'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'PT',
#   'Date': '2021-01-27 15:51:41'},
#  {'City': 'Xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 40.14,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 5.84,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:51:42'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 84.2,
#   'Humidity': 61,
#   'Cloudiness': 35,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:51:42'},
#  {'City': 'Kadoshkino',
#   'Lat': 54.0257,
#   'Lng': 44.4191,
#   'Max Temp': 30.99,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 17.02,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:42'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': -9.4,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:51:42'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 64,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:51:43'},
#  {'City': 'Lucea',
#   'Lat': 18.451,
#   'Lng': -78.1736,
#   'Max Temp': 84.99,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'JM',
#   'Date': '2021-01-27 15:51:43'},
#  {'City': 'Zelenogorskiy',
#   'Lat': 55.0333,
#   'Lng': 87,
#   'Max Temp': 24.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 15.66,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:43'},
#  {'City': 'Metro',
#   'Lat': -5.1131,
#   'Lng': 105.3067,
#   'Max Temp': 75.94,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 0.81,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:51:43'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 21.63,
#   'Humidity': 79,
#   'Cloudiness': 50,
#   'Wind Speed': 3.83,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:51:44'},
#  {'City': 'Matiri',
#   'Lat': -10.75,
#   'Lng': 34.9,
#   'Max Temp': 68.09,
#   'Humidity': 95,
#   'Cloudiness': 30,
#   'Wind Speed': 1.63,
#   'Country': 'TZ',
#   'Date': '2021-01-27 15:51:44'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': -23.8,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-01-27 15:49:41'},
#  {'City': 'Erenhot',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': -6.38,
#   'Humidity': 85,
#   'Cloudiness': 79,
#   'Wind Speed': 13.6,
#   'Country': 'CN',
#   'Date': '2021-01-27 15:51:44'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 64,
#   'Humidity': 87,
#   'Cloudiness': 31,
#   'Wind Speed': 8.01,
#   'Country': 'PT',
#   'Date': '2021-01-27 15:51:45'},
#  {'City': 'Timbiqui',
#   'Lat': 2.7717,
#   'Lng': -77.6654,
#   'Max Temp': 82.76,
#   'Humidity': 76,
#   'Cloudiness': 69,
#   'Wind Speed': 4.12,
#   'Country': 'CO',
#   'Date': '2021-01-27 15:51:45'},
#  {'City': 'Bauta',
#   'Lat': 22.9828,
#   'Lng': -82.5464,
#   'Max Temp': 79.48,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 6.42,
#   'Country': 'CU',
#   'Date': '2021-01-27 15:51:45'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 37.99,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-01-27 15:50:59'},
#  {'City': 'Upata',
#   'Lat': 8.0086,
#   'Lng': -62.3989,
#   'Max Temp': 84,
#   'Humidity': 66,
#   'Cloudiness': 58,
#   'Wind Speed': 7,
#   'Country': 'VE',
#   'Date': '2021-01-27 15:51:46'},
#  {'City': 'Batamshinskiy',
#   'Lat': 50.5594,
#   'Lng': 58.2747,
#   'Max Temp': 5,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'KZ',
#   'Date': '2021-01-27 15:51:46'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'GF',
#   'Date': '2021-01-27 15:51:46'},
#  {'City': 'Qurbus',
#   'Lat': 36.8167,
#   'Lng': 10.5687,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'TN',
#   'Date': '2021-01-27 15:51:47'},
#  {'City': 'Cavalcante',
#   'Lat': -13.7975,
#   'Lng': -47.4583,
#   'Max Temp': 80.96,
#   'Humidity': 63,
#   'Cloudiness': 84,
#   'Wind Speed': 6.76,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:51:47'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 45.82,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 13.6,
#   'Country': 'TM',
#   'Date': '2021-01-27 15:51:47'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 12.2,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:47'},
#  {'City': 'Madang',
#   'Lat': -5.2246,
#   'Lng': 145.7966,
#   'Max Temp': 76.95,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.22,
#   'Country': 'PG',
#   'Date': '2021-01-27 15:51:47'},
#  {'City': 'Sampit',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 74.79,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:51:48'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 24.8,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 25.32,
#   'Country': 'NO',
#   'Date': '2021-01-27 15:51:48'},
#  {'City': 'Florianopolis',
#   'Lat': -27.6146,
#   'Lng': -48.5012,
#   'Max Temp': 89.6,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:51:48'},
#  {'City': 'Baglan',
#   'Lat': 36.1307,
#   'Lng': 68.7083,
#   'Max Temp': 38.82,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 1.79,
#   'Country': 'AF',
#   'Date': '2021-01-27 15:51:48'},
#  {'City': 'Yarim',
#   'Lat': 14.298,
#   'Lng': 44.3779,
#   'Max Temp': 55.13,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Country': 'YE',
#   'Date': '2021-01-27 15:51:10'},
#  {'City': 'Kendari',
#   'Lat': -3.945,
#   'Lng': 122.4989,
#   'Max Temp': 77.2,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Country': 'ID',
#   'Date': '2021-01-27 15:51:49'},
#  {'City': 'Torit',
#   'Lat': 4.4133,
#   'Lng': 32.5678,
#   'Max Temp': 92.61,
#   'Humidity': 18,
#   'Cloudiness': 85,
#   'Wind Speed': 7.09,
#   'Country': 'SS',
#   'Date': '2021-01-27 15:51:49'},
#  {'City': 'Santa Cruz Cabralia',
#   'Lat': -16.2781,
#   'Lng': -39.0247,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-01-27 15:51:49'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Country': 'PG',
#   'Date': '2021-01-27 15:51:49'},
#  {'City': 'Iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': -7.19,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 15.26,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:50'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 75,
#   'Humidity': 83,
#   'Cloudiness': 37,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-01-27 15:51:50'},
#  {'City': 'Smolenka',
#   'Lat': 52.1352,
#   'Lng': 113.4974,
#   'Max Temp': -14.8,
#   'Humidity': 64,
#   'Cloudiness': 99,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': '2021-01-27 15:51:50'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Qaanaaq  77.4840  -69.3632    -14.98        64           0
# 1           Male   4.1748   73.5089     82.40        65          75
# 2         Albany  42.6001  -73.9662     30.99        65          92
# 3        Ushuaia -54.8000  -68.3000     44.60        70          75
# 4     Dawlatabad  36.4141   64.9053     40.53        66           0
# 5        Rikitea -23.1203 -134.9692     79.77        71           0
# 6  Mar Del Plata -38.0023  -57.5575     71.60        56          20
# 7       Souillac -20.5167   57.5167     82.40        65          20
# 8     Codrington -38.2667  141.9667     57.04        86           2
# 9     Kuybysheve  47.3580   36.6491     43.39        71         100
#
#    Wind Speed Country                 Date
# 0        5.99      GL  2021-01-27 15:49:39
# 1       12.66      MV  2021-01-27 15:49:39
# 2       11.99      US  2021-01-27 15:47:09
# 3       16.11      AR  2021-01-27 15:48:19
# 4        3.38      AF  2021-01-27 15:49:40
# 5       14.65      PF  2021-01-27 15:49:40
# 6       16.11      AR  2021-01-27 15:45:34
# 7        3.44      MU  2021-01-27 15:49:41
# 8        9.86      AU  2021-01-27 15:49:41
# 9       18.75      UA  2021-01-27 15:49:41

# %%
new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country                 Date      Lat      Lng  Max Temp  \
# 0     Qaanaaq      GL  2021-01-27 15:49:39  77.4840 -69.3632    -14.98
# 1        Male      MV  2021-01-27 15:49:39   4.1748  73.5089     82.40
# 2      Albany      US  2021-01-27 15:47:09  42.6001 -73.9662     30.99
# 3     Ushuaia      AR  2021-01-27 15:48:19 -54.8000 -68.3000     44.60
# 4  Dawlatabad      AF  2021-01-27 15:49:40  36.4141  64.9053     40.53
#
#    Humidity  Cloudiness  Wind Speed
# 0        64           0        5.99
# 1        65          75       12.66
# 2        65          92       11.99
# 3        70          75       16.11
# 4        66           0        3.38

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '01/27/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
